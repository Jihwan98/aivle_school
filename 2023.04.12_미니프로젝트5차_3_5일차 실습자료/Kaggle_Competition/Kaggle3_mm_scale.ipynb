# %%
# library import
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import tensorflow as tf
import numpy as np
import random
import os

def my_seed_everywhere(seed: int = 42):
    random.seed(seed) # random
    np.random.seed(seed) # np
    os.environ["PYTHONHASHSEED"] = str(seed) # os
    tf.random.set_seed(seed) # tensorflow

my_seed = 42
my_seed_everywhere(my_seed)

# %%
# data 확인
train_path = 'data/train_dataset.csv'
test_path = 'data/test_dataset.csv'

train_data = pd.read_csv(train_path)
x_test = pd.read_csv(test_path)

train_data.shape, x_test.shape
# Out:
# ((5881, 52), (1471, 50))

# %%
from sklearn.preprocessing import MinMaxScaler
mm_scaler = MinMaxScaler()
temp_x = train_data.drop(['Activity', 'Activity_dynamic'], axis=1)
temp_x = mm_scaler.fit_transform(temp_x)

# %%
pd.DataFrame(temp_x, columns=[list(train_data)[:-2]])
# Out:
#      tBodyAcc-mean()-Z tBodyAcc-arCoeff()-X,2 tBodyAcc-arCoeff()-Y,1  \
# 0             0.448319               0.447229               0.445396
# 1             0.450918               0.469018               0.732382
# 2             0.445641               0.379275               0.650582
# 3             0.424823               0.778998               0.307941
# 4             0.545615               0.448901               0.194603
# ...                ...                    ...                    ...
# 5876          0.434013               0.465618               0.500220
# 5877          0.447413               0.637774               0.404305
# 5878          0.446280               0.483090               0.703809
# 5879          0.439500               0.849437               0.196991
# 5880          0.430991               0.354189               0.420685
#
#      tBodyAccJerk-mean()-X tBodyAccJerk-mean()-Y tBodyAccJerk-arCoeff()-X,2  \
# 0                 0.534292              0.492843                   0.614582
# 1                 0.537974              0.502228                   0.579566
# 2                 0.539765              0.507252                   0.569840
# 3                 0.345245              0.399354                   0.723856
# 4                 0.792106              0.366592                   0.385231
# ...                    ...                   ...                        ...
# 5876              0.541196              0.495633                   0.605125
# 5877              0.445851              0.525288                   0.599053
# 5878              0.535371              0.505674                   0.626798
# 5879              0.457078              0.480402                   0.768843
# 5880              0.539778              0.440272                   0.526928
#
#      tBodyAccJerk-arCoeff()-Y,1 tBodyAccJerk-arCoeff()-Y,3  \
# 0                      0.463167                   0.568554
# 1                      0.700956                   0.772599
# 2                      0.631778                   0.798220
# 3                      0.313690                   0.658070
# 4                      0.185574                   0.559455
# ...                         ...                        ...
# 5876                   0.520506                   0.599205
# 5877                   0.343252                   0.476330
# 5878                   0.629726                   0.764954
# 5879                   0.185966                   0.683271
# 5880                   0.474411                   0.571358
#
#      tBodyAccJerk-arCoeff()-Z,1 tBodyGyro-arCoeff()-Z,3  ...  \
# 0                      0.489135                0.668398  ...
# 1                      0.525651                0.745015  ...
# 2                      0.682830                0.554287  ...
# 3                      0.384665                0.120890  ...
# 4                      0.394503                0.329348  ...
# ...                         ...                     ...  ...
# 5876                   0.518822                0.701988  ...
# 5877                   0.515924                0.352664  ...
# 5878                   0.616595                0.566344  ...
# 5879                   0.499931                0.368673  ...
# 5880                   0.603049                0.746228  ...
#
#      fBodyAccJerk-bandsEnergy()-41,48.2 fBodyAccJerk-bandsEnergy()-49,64.2  \
# 0                              0.000160                           0.000141
# 1                              0.000086                           0.000209
# 2                              0.000211                           0.000361
# 3                              0.029553                           0.076001
# 4                              0.008370                           0.036377
# ...                                 ...                                ...
# 5876                           0.000255                           0.000534
# 5877                           0.021738                           0.033471
# 5878                           0.000242                           0.000091
# 5879                           0.020464                           0.011367
# 5880                           0.000487                           0.000810
#
#      fBodyGyro-min()-Y fBodyGyro-bandsEnergy()-49,64.1  \
# 0             0.001889                        0.000015
# 1             0.004077                        0.000030
# 2             0.000014                        0.000012
# 3             0.068815                        0.015335
# 4             0.022235                        0.004854
# ...                ...                             ...
# 5876          0.001122                        0.000016
# 5877          0.027155                        0.008789
# 5878          0.001014                        0.000040
# 5879          0.173878                        0.029745
# 5880          0.051918                        0.001342
#
#      fBodyBodyAccJerkMag-iqr() fBodyBodyAccJerkMag-entropy()  \
# 0                     0.007181                      0.000000
# 1                     0.005260                      0.000000
# 2                     0.003983                      0.000000
# 3                     0.306143                      0.661630
# 4                     0.389366                      0.723193
# ...                        ...                           ...
# 5876                  0.006037                      0.000000
# 5877                  0.219126                      0.620684
# 5878                  0.004909                      0.000000
# 5879                  0.267051                      0.661701
# 5880                  0.010123                      0.000000
#
#      fBodyBodyGyroMag-mean() fBodyBodyGyroJerkMag-min()  \
# 0                   0.012283                   0.003018
# 1                   0.010733                   0.002633
# 2                   0.004024                   0.003900
# 3                   0.260205                   0.055387
# 4                   0.283317                   0.094777
# ...                      ...                        ...
# 5876                0.009441                   0.008118
# 5877                0.292391                   0.077277
# 5878                0.004274                   0.005484
# 5879                0.247838                   0.066003
# 5880                0.025042                   0.005950
#
#      fBodyBodyGyroJerkMag-meanFreq() angle(tBodyAccMean,gravity)
# 0                           0.488133                    0.472577
# 1                           0.375973                    0.462253
# 2                           0.708258                    0.494210
# 3                           0.531583                    0.365002
# 4                           0.497705                    0.471641
# ...                              ...                         ...
# 5876                        0.532643                    0.476425
# 5877                        0.675157                    0.859210
# 5878                        0.694492                    0.524518
# 5879                        0.521662                    0.626061
# 5880                        0.747095                    0.548559
#
# [5881 rows x 50 columns]

# %%
temp_x = pd.DataFrame(temp_x, columns=[list(train_data)[:-2]])

# %%
temp_y = train_data[['Activity', 'Activity_dynamic']]

# %%
pd.concat([temp_x, temp_y], axis=1, join='outer')
# Out:
#       (tBodyAcc-mean()-Z,)  (tBodyAcc-arCoeff()-X,2,)  \
# 0                 0.448319                   0.447229
# 1                 0.450918                   0.469018
# 2                 0.445641                   0.379275
# 3                 0.424823                   0.778998
# 4                 0.545615                   0.448901
# ...                    ...                        ...
# 5876              0.434013                   0.465618
# 5877              0.447413                   0.637774
# 5878              0.446280                   0.483090
# 5879              0.439500                   0.849437
# 5880              0.430991                   0.354189
#
#       (tBodyAcc-arCoeff()-Y,1,)  (tBodyAccJerk-mean()-X,)  \
# 0                      0.445396                  0.534292
# 1                      0.732382                  0.537974
# 2                      0.650582                  0.539765
# 3                      0.307941                  0.345245
# 4                      0.194603                  0.792106
# ...                         ...                       ...
# 5876                   0.500220                  0.541196
# 5877                   0.404305                  0.445851
# 5878                   0.703809                  0.535371
# 5879                   0.196991                  0.457078
# 5880                   0.420685                  0.539778
#
#       (tBodyAccJerk-mean()-Y,)  (tBodyAccJerk-arCoeff()-X,2,)  \
# 0                     0.492843                       0.614582
# 1                     0.502228                       0.579566
# 2                     0.507252                       0.569840
# 3                     0.399354                       0.723856
# 4                     0.366592                       0.385231
# ...                        ...                            ...
# 5876                  0.495633                       0.605125
# 5877                  0.525288                       0.599053
# 5878                  0.505674                       0.626798
# 5879                  0.480402                       0.768843
# 5880                  0.440272                       0.526928
#
#       (tBodyAccJerk-arCoeff()-Y,1,)  (tBodyAccJerk-arCoeff()-Y,3,)  \
# 0                          0.463167                       0.568554
# 1                          0.700956                       0.772599
# 2                          0.631778                       0.798220
# 3                          0.313690                       0.658070
# 4                          0.185574                       0.559455
# ...                             ...                            ...
# 5876                       0.520506                       0.599205
# 5877                       0.343252                       0.476330
# 5878                       0.629726                       0.764954
# 5879                       0.185966                       0.683271
# 5880                       0.474411                       0.571358
#
#       (tBodyAccJerk-arCoeff()-Z,1,)  (tBodyGyro-arCoeff()-Z,3,)  ...  \
# 0                          0.489135                    0.668398  ...
# 1                          0.525651                    0.745015  ...
# 2                          0.682830                    0.554287  ...
# 3                          0.384665                    0.120890  ...
# 4                          0.394503                    0.329348  ...
# ...                             ...                         ...  ...
# 5876                       0.518822                    0.701988  ...
# 5877                       0.515924                    0.352664  ...
# 5878                       0.616595                    0.566344  ...
# 5879                       0.499931                    0.368673  ...
# 5880                       0.603049                    0.746228  ...
#
#       (fBodyGyro-min()-Y,)  (fBodyGyro-bandsEnergy()-49,64.1,)  \
# 0                 0.001889                            0.000015
# 1                 0.004077                            0.000030
# 2                 0.000014                            0.000012
# 3                 0.068815                            0.015335
# 4                 0.022235                            0.004854
# ...                    ...                                 ...
# 5876              0.001122                            0.000016
# 5877              0.027155                            0.008789
# 5878              0.001014                            0.000040
# 5879              0.173878                            0.029745
# 5880              0.051918                            0.001342
#
#       (fBodyBodyAccJerkMag-iqr(),)  (fBodyBodyAccJerkMag-entropy(),)  \
# 0                         0.007181                          0.000000
# 1                         0.005260                          0.000000
# 2                         0.003983                          0.000000
# 3                         0.306143                          0.661630
# 4                         0.389366                          0.723193
# ...                            ...                               ...
# 5876                      0.006037                          0.000000
# 5877                      0.219126                          0.620684
# 5878                      0.004909                          0.000000
# 5879                      0.267051                          0.661701
# 5880                      0.010123                          0.000000
#
#       (fBodyBodyGyroMag-mean(),)  (fBodyBodyGyroJerkMag-min(),)  \
# 0                       0.012283                       0.003018
# 1                       0.010733                       0.002633
# 2                       0.004024                       0.003900
# 3                       0.260205                       0.055387
# 4                       0.283317                       0.094777
# ...                          ...                            ...
# 5876                    0.009441                       0.008118
# 5877                    0.292391                       0.077277
# 5878                    0.004274                       0.005484
# 5879                    0.247838                       0.066003
# 5880                    0.025042                       0.005950
#
#       (fBodyBodyGyroJerkMag-meanFreq(),)  (angle(tBodyAccMean,gravity),)  \
# 0                               0.488133                        0.472577
# 1                               0.375973                        0.462253
# 2                               0.708258                        0.494210
# 3                               0.531583                        0.365002
# 4                               0.497705                        0.471641
# ...                                  ...                             ...
# 5876                            0.532643                        0.476425
# 5877                            0.675157                        0.859210
# 5878                            0.694492                        0.524518
# 5879                            0.521662                        0.626061
# 5880                            0.747095                        0.548559
#
#                 Activity  Activity_dynamic
# 0               STANDING                 4
# 1                 LAYING                 3
# 2               STANDING                 4
# 3                WALKING                 0
# 4     WALKING_DOWNSTAIRS                 2
# ...                  ...               ...
# 5876             SITTING                 5
# 5877    WALKING_UPSTAIRS                 1
# 5878              LAYING                 3
# 5879    WALKING_UPSTAIRS                 1
# 5880             SITTING                 5
#
# [5881 rows x 52 columns]

# %%
train_data = pd.concat([temp_x, temp_y], axis=1, join='outer')
