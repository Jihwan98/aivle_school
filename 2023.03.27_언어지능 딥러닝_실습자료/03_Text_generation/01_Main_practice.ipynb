# %% [markdown]
# # Text Generation
#
# * 시점별로, 준비된 단어들 중 어떤 단어를 가져와야 적절할지 '선택'하는 문제이다.
# * 선택이란 곧, 분류이다.( 적절한 선택 or 그렇지 않은 선택들 )
# * 당연히, 데이터가 엄청 많아야 '작사'다울 수 있다.
# * 데이터가 부족한 지금은, 모델은 고장난 앵무새일 수 밖에 없다.

# %% [markdown]
# # Data : 야생화, 바람기억, 숨
#
# **조건**
# 1. 원하는 노래가사로 변경해도 좋다. 하지만 아래의 포맷을 맞추어 내야 코드를 재사용할 수 있다.

# %%
# 처음 설치할때만 실행하고, 그 후에는 주석처리 하세요.
# !pip install konlpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting konlpy
#   Downloading konlpy-0.6.0-py2.py3-none-any.whl (19.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.4/19.4 MB 35.3 MB/s eta 0:00:00
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.9/dist-packages (from konlpy) (4.9.2)
# Collecting JPype1>=0.7.0
#   Downloading JPype1-1.4.1-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (465 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 465.3/465.3 KB 24.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.9/dist-packages (from konlpy) (1.22.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from JPype1>=0.7.0->konlpy) (23.0)
# Installing collected packages: JPype1, konlpy
# Successfully installed JPype1-1.4.1 konlpy-0.6.0

# %%
import numpy as np
import pandas as pd

# %%
gasa1 = "하얗게 피어난 얼음 꽃 하나가\n달가운 바람에 얼굴을 내밀어\n아무 말 못했던 이름도 몰랐던\n지나간 날들에 눈물이 흘러\n차가운 바람에 숨어 있다\n한줄기 햇살에 몸 녹이다\n그렇게 너는 또 한번 내게 온다\n좋았던 기억만\n그리운 마음만\n니가 떠나간 그 길 위에\n이렇게 남아 서 있다\n잊혀질 만큼만\n괜찮을 만큼만\n눈물 머금고 기다린 떨림 끝에\n다시 나를 피우리라\n사랑은 피고 또 지는 타버리는 불꽃\n빗물에 젖을까 두 눈을 감는다\n어리고 작았던 나의 맘에\n눈부시게 빛나던 추억 속에\n그렇게 너를 또 한번 불러본다\n좋았던 기억만\n그리운 마음만\n니가 떠나간 그 길 위에\n이렇게 남아 서 있다\n잊혀질 만큼만\n괜찮을 만큼만\n눈물 머금고 기다린 떨림\n끝에 다시 나는\n메말라가는 땅 위에\n온몸이 타 들어가고\n내 손끝에 남은\n너의 향기 흩어져 날아가\n멀어져 가는 너의 손을\n붙잡지 못해 아프다\n살아갈 만큼만\n미워했던 만큼만\n먼 훗날 너를 데려다 줄\n그 봄이 오면\n그날에 나 피우리라"
gasa2 = """바람 불어와 내 맘 흔들면
지나간 세월에
두 눈을 감아본다
나를 스치는 고요한 떨림
그 작은 소리에
난 귀를 기울여 본다
내 안에 숨쉬는
커버린 삶의 조각들이
날 부딪혀 지날 때
그 곳을 바라보리라
우리의 믿음 우리의 사랑
그 영원한 약속들을
나 추억한다면 힘차게 걸으리라
우리의 만남 우리의 이별
그 바래진 기억에
나 사랑했다면 미소를 띄우리라
내 안에 있는
모자란 삶의 기억들이
날 부딪혀 지날 때
그 곳을 바라보리라
우리의 믿음 우리의 사랑
그 영원한 약속들을
나 추억한다면 힘차게 걸으리라
우리의 만남 우리의 이별
그 바래진 기억에
나 사랑했다면 미소를 띄우리라"""
gasa3 = "오늘 하루 쉴 숨이\n오늘 하루 쉴 곳이\n오늘만큼 이렇게 또 한번 살아가\n침대 밑에 놓아둔\n지난 밤에 꾼 꿈이\n지친 맘을 덮으며\n눈을 감는다 괜찮아\n남들과는 조금은 다른 모양 속에\n나 홀로 잠들어\n다시 오는 아침에\n눈을 뜨면 웃고프다\n오늘 같은 밤\n이대로 머물러도 될 꿈이라면\n바랄 수 없는걸 바라도 된다면\n두렵지 않다면 너처럼\n오늘 같은 날\n마른 줄 알았던\n오래된 눈물이 흐르면\n잠들지 않는 내 작은 가슴이\n숨을 쉰다\n끝도 없이 먼 하늘\n날아가는 새처럼\n뒤돌아 보지 않을래\n이 길 너머 어딘가 봄이\n힘없이 멈춰있던\n세상에 비가 내리고\n다시 자라난 오늘\n그 하루를 살아\n오늘 같은 밤\n이대로 머물러도 될 꿈이라면\n바랄 수 없는걸 바라도 된다면\n두렵지 않다면 너처럼\n오늘 같은 날\n마른 줄 알았던\n오래된 눈물이 흐르면\n잠들지 않는\n이 어린 가슴이 숨을 쉰다\n고단했던 내 하루가\n숨을 쉰다"

# %%
gasa1_ = gasa1.split("\n")
gasa2_ = gasa2.split("\n")
gasa3_ = gasa3.split("\n")

gasa = gasa1_ + gasa2_ + gasa3_

# %%
from konlpy.tag import Okt
okt = Okt()

# 이랬던 문장이.
print("원본 문장 : ", gasa[1]) 

# 이렇게 바뀝니다. okt.morphs가 형태소 분석기에요.
형태소토큰 = okt.morphs(gasa[1])
print("형태소 기준으로 tokenize : ", 형태소토큰) 

# 이러면 배운 대로, 띄어쓰기 기준 token을 사용할 수 있겠죠?
다시문장으로 = " ".join(형태소토큰)
print("다시 문장으로 : ", 다시문장으로)
# Out:
# 원본 문장 :  달가운 바람에 얼굴을 내밀어
# 형태소 기준으로 tokenize :  ['달', '가운', '바람', '에', '얼굴', '을', '내밀어']
# 다시 문장으로 :  달 가운 바람 에 얼굴 을 내밀어

# %% [markdown]
# # Q1. gasa안의 모든 문장에, 형태소 사이 사이에 띄어쓰기를 추가하라.
#
# **힌트**
# 1. 위의 코드를 적극 참고할 것.
# 2. 루프

# %%
####################
## Your Code here ##
####################
X = []
for g in gasa:
    X.append(' '.join(okt.morphs(g)))

X[:3]
# Out:
# ['하얗게 피어 난 얼음 꽃 하나 가', '달 가운 바람 에 얼굴 을 내밀어', '아무 말 못 했던 이름 도 몰랐던']

# %% [markdown]
# # Q2. gasa를 띄어쓰기 기준으로 tokenize하고, index의 sequence로 바꾸어 내시오.
#
# **조건**
# 0. gasa_seq에, index의 seq로 바뀐 가사를 선언해둔다.
# 1. 데이터가 부족하다, 모든 단어 다 사용할 것.
# 2. vocab_size라는 변수에 사용하게 될 token의 수를 선언해두자.
#     * 힌트1 : 토크나이저.index_word , 인덱스가 몇부터 시작하는가?
#     * 힌트2 : 패딩, 0을 덧댈것이다. (0이 인덱스이자 덧댐을 의미하는 token이 될 것이다.)
#     * 힌트3 : embedding 때도, index:0이 필요하다.
#     * 힌트4 : 원핫인코딩도, 0부터 시작하기 때문에, 0이 필요하다.
#     * 힌트5 : 심지어, Tokenizer도, num_words = 1000을 둔다면, 상위 999개 token만 사용한다. (우리가 0을 추가로 사용할 것을 가정함. 결국 1000개가 됨.)

# %%
####################
## Your Code here ##
####################
from tensorflow.keras.preprocessing.text import Tokenizer
tokenizer = Tokenizer(lower=False)

# %%
# %%time
tokenizer.fit_on_texts(X)
gasa_seq = tokenizer.texts_to_sequences(X)
# Out:
# CPU times: user 1.85 ms, sys: 0 ns, total: 1.85 ms
# Wall time: 2.11 ms

# %%
vocab_size = len(tokenizer.index_word) + 1

# %% [markdown]
# # Q3. gasa_seq안의 모든 문장을 다음과 같이 재구성하시오.
#
# **예시**
# * gasa_seq가 [ [1,2,3], [7,2,9,10] ] 라면
# * 결과 : gasa_seq = [ [1, 2], [1,2,3], [7,2], [7,2,9], [7,2,9,10] ]
# * 중간에 다른 변수를 임시로 사용해도 좋다.

# %%
gasa_seq[:5]
# Out:
# [[110, 111, 43, 112, 113, 114, 14],
#  [115, 116, 26, 1, 117, 3, 118],
#  [119, 120, 44, 45, 121, 46, 122],
#  [47, 15, 10, 1, 16, 2, 123],
#  [124, 26, 1, 125, 27]]

# %%
####################
## Your Code here ##
####################
temp = []
max_len = 0
for g in gasa_seq:
    max_len = max(max_len, len(g))
    for i in range(1, len(g)):
        temp.append(np.array(g[:i + 1]))
temp[:5], max_len
# Out:
# ([array([110, 111]),
#   array([110, 111,  43]),
#   array([110, 111,  43, 112]),
#   array([110, 111,  43, 112, 113]),
#   array([110, 111,  43, 112, 113, 114])],
#  9)

# %%
gasa_seq = temp

# %% [markdown]
# # Q4. gasa_seq안의 가장 긴 문장을 찾고, 그 길이에 맞추어 문장 길이를 통일하시오.
#
# **Questions**
# 1. 0을 앞에 덧대야 할까, 뒤에 덧대야 할까?
# 2. 문장의 길이가 매우 길다면, 가장 긴 문장에 맞추어 길이를 통일하는 것이 좋은 방법일까?
# 3. gasa_seq의 shape를 확인하라.

# %%
####################
## Your Code here ##
####################
from tensorflow.keras.preprocessing.sequence import pad_sequences

gasa_seq = pad_sequences(gasa_seq, maxlen=max_len, padding='pre')

gasa_seq.shape
# Out:
# (382, 9)

# %% [markdown]
# # Q5. gasa_seq의 마지막 컬럼은 y로, 나머지 컬럼은 x로 분할하라.

# %%
####################
## Your Code here ##
####################

x = gasa_seq[:, :-1]
y = gasa_seq[:, -1]

# %% [markdown]
# # Q6. y를, vocab_size에 맞추어 원핫 인코딩 하시오.
#
# 1. num_classes 를 반드시 vocab_size에 맞출 것.
# 2. 사용하지 않을 컬럼이 존재할 수 있다.
#     * 예시) y에는 4가 없는데, 0으로만 가득찬 4번 컬럼이 만들어질 수도 있다.
#
# **추가설명**
# * 효율을 위해, 이 모든걸 엄격히 보정하여 사용할 수도 있다.
# * 그러나, 코드가 매우 길어진다.
# * 데이터가 많아지면, 별차이도 없어진다.

# %%
####################
## Your Code here ##
####################
from tensorflow.keras.utils import to_categorical

y = to_categorical(y, num_classes=vocab_size)

# %% [markdown]
# # Q7. 문장을 받아, 다음 단어를 선택하는 모델을 만드시오.
#
# * 컴파일까지 마치시오.
#     * 모니터링 지표로 accuracy 사용0
# * 모델 구조는 아래와 같다.
#     1. 임베딩 레이어 : 임베딩 차원 32, input_length 주의. gasa_seq를 x와 y로 분할했기 때문에, 문장길이가 달라졌다.
#     2. GRU, 32, 모든 출력을 다음 layer로
#     3. GRU, 48, 모든 출력을 다음 layer로
#     4. GRU, 64, 마지막 출력만 다음 레이어로.
#     5. 멀티클래스 분류 아웃풋레이어

# %%
####################
## Your Code here ##
####################
import tensorflow as tf
from tensorflow import keras
import tensorflow.keras.backend as K
from tensorflow.keras.layers import Input, Dense, Flatten, Conv1D, MaxPool1D
from tensorflow.keras.layers import GRU, Embedding
from tensorflow.keras.models import Model

# %%
x.shape
# Out:
# (382, 8)

# %%
####################
## Your Code here ##
####################

# 세션 클리어
K.clear_session()

# 모델 쌓기
# 0. Input
il = Input(shape=(max_len - 1))

# 1. 임베딩 레이어 : 임베딩 차원 32, input_length 주의. gasa_seq를 x와 y로 분할했기 때문에, 문장길이가 달라졌다.
hl = Embedding(vocab_size, 32, input_length=max_len - 1)(il)

# 2. GRU, 32, 모든 출력을 다음 layer로
hl = GRU(32, return_sequences=True)(hl)
# 3. GRU, 48, 모든 출력을 다음 layer로
hl = GRU(48, return_sequences=True)(hl)
# 4. GRU, 64, 마지막 출력만 다음 레이어로.
hl = GRU(64, return_sequences=False)(hl)
# 5. 멀티클래스 분류 아웃풋레이어
ol = Dense(vocab_size, activation='softmax')(hl)

# 모델 선언
model = Model(il, ol)

# 컴파일
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

# 요약
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 8)]               0
#
#  embedding (Embedding)       (None, 8, 32)             7200
#
#  gru (GRU)                   (None, 8, 32)             6336
#
#  gru_1 (GRU)                 (None, 8, 48)             11808
#
#  gru_2 (GRU)                 (None, 64)                21888
#
#  dense (Dense)               (None, 225)               14625
#
# =================================================================
# Total params: 61,857
# Trainable params: 61,857
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Q8. 모델을 학습시킬 것.
#
# * batch_size = 64
# * epochs = 1000

# %%
####################
## Your Code here ##
####################
history = model.fit(x, y, epochs=1000, batch_size=64)
# Out:
# Epoch 1/1000
# 6/6 [==============================] - 15s 161ms/step - loss: 5.4145 - accuracy: 0.0340
# Epoch 2/1000
# 6/6 [==============================] - 1s 131ms/step - loss: 5.4007 - accuracy: 0.0654
# Epoch 3/1000
# 6/6 [==============================] - 1s 99ms/step - loss: 5.3713 - accuracy: 0.0654
# Epoch 4/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 5.2955 - accuracy: 0.0654
# Epoch 5/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 5.0981 - accuracy: 0.0654
# Epoch 6/1000
# 6/6 [==============================] - 0s 39ms/step - loss: 5.0484 - accuracy: 0.0654
# Epoch 7/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 4.9788 - accuracy: 0.0654
# Epoch 8/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 4.9305 - accuracy: 0.0654
# Epoch 9/1000
# 6/6 [==============================] - 0s 70ms/step - loss: 4.9174 - accuracy: 0.0654
# Epoch 10/1000
# 6/6 [==============================] - 0s 38ms/step - loss: 4.9041 - accuracy: 0.0654
# Epoch 11/1000
# 6/6 [==============================] - 0s 38ms/step - loss: 4.8899 - accuracy: 0.0654
# Epoch 12/1000
# 6/6 [==============================] - 0s 38ms/step - loss: 4.8863 - accuracy: 0.0654
# Epoch 13/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 4.8789 - accuracy: 0.0654
# Epoch 14/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 4.8720 - accuracy: 0.0654
# Epoch 15/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 4.8649 - accuracy: 0.0654
# Epoch 16/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 4.8566 - accuracy: 0.0654
# Epoch 17/1000
# 6/6 [==============================] - 0s 56ms/step - loss: 4.8465 - accuracy: 0.0654
# Epoch 18/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 4.8326 - accuracy: 0.0654
# Epoch 19/1000
# 6/6 [==============================] - 0s 12ms/step - loss: 4.8185 - accuracy: 0.0654
# Epoch 20/1000
# 6/6 [==============================] - 0s 12ms/step - loss: 4.7982 - accuracy: 0.0654
# Epoch 21/1000
# 6/6 [==============================] - 0s 60ms/step - loss: 4.7730 - accuracy: 0.0654
# Epoch 22/1000
# 6/6 [==============================] - 1s 50ms/step - loss: 4.7427 - accuracy: 0.0681
# Epoch 23/1000
# 6/6 [==============================] - 0s 38ms/step - loss: 4.7064 - accuracy: 0.0759
# Epoch 24/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 4.6610 - accuracy: 0.0812
# Epoch 25/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 4.6057 - accuracy: 0.0864
# Epoch 26/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 4.5416 - accuracy: 0.0995
# Epoch 27/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 4.4760 - accuracy: 0.0995
# Epoch 28/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 4.4030 - accuracy: 0.1021
# Epoch 29/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 4.3320 - accuracy: 0.1152
# Epoch 30/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 4.2640 - accuracy: 0.1099
# Epoch 31/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 4.1823 - accuracy: 0.1204
# Epoch 32/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 4.1087 - accuracy: 0.1283
# Epoch 33/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 4.0350 - accuracy: 0.1335
# Epoch 34/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 3.9620 - accuracy: 0.1440
# Epoch 35/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 3.8852 - accuracy: 0.1545
# Epoch 36/1000
# 6/6 [==============================] - 0s 39ms/step - loss: 3.8150 - accuracy: 0.1675
# Epoch 37/1000
# 6/6 [==============================] - 0s 39ms/step - loss: 3.7450 - accuracy: 0.1806
# Epoch 38/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 3.6799 - accuracy: 0.1885
# Epoch 39/1000
# 6/6 [==============================] - 0s 37ms/step - loss: 3.6217 - accuracy: 0.1911
# Epoch 40/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 3.5447 - accuracy: 0.1937
# Epoch 41/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 3.4877 - accuracy: 0.2173
# Epoch 42/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 3.4181 - accuracy: 0.2435
# Epoch 43/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 3.3601 - accuracy: 0.2513
# Epoch 44/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 3.2990 - accuracy: 0.2565
# Epoch 45/1000
# 6/6 [==============================] - 0s 38ms/step - loss: 3.2396 - accuracy: 0.2749
# Epoch 46/1000
# 6/6 [==============================] - 0s 38ms/step - loss: 3.1796 - accuracy: 0.2906
# Epoch 47/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 3.1218 - accuracy: 0.3089
# Epoch 48/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 3.0662 - accuracy: 0.3194
# Epoch 49/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 3.0117 - accuracy: 0.3220
# Epoch 50/1000
# 6/6 [==============================] - 0s 37ms/step - loss: 2.9595 - accuracy: 0.3272
# Epoch 51/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 2.9046 - accuracy: 0.3246
# Epoch 52/1000
# 6/6 [==============================] - 0s 38ms/step - loss: 2.8515 - accuracy: 0.3246
# Epoch 53/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 2.8042 - accuracy: 0.3325
# Epoch 54/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 2.7604 - accuracy: 0.3455
# Epoch 55/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 2.7116 - accuracy: 0.3586
# Epoch 56/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 2.6609 - accuracy: 0.3639
# Epoch 57/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 2.6187 - accuracy: 0.3717
# Epoch 58/1000
# 6/6 [==============================] - 0s 39ms/step - loss: 2.5646 - accuracy: 0.3927
# Epoch 59/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 2.5186 - accuracy: 0.4162
# Epoch 60/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 2.4753 - accuracy: 0.4136
# Epoch 61/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 2.4290 - accuracy: 0.4529
# Epoch 62/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 2.3874 - accuracy: 0.4607
# Epoch 63/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 2.3420 - accuracy: 0.4686
# Epoch 64/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 2.2994 - accuracy: 0.4895
# Epoch 65/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 2.2614 - accuracy: 0.4921
# Epoch 66/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 2.2250 - accuracy: 0.4895
# Epoch 67/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 2.1799 - accuracy: 0.5105
# Epoch 68/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 2.1384 - accuracy: 0.5105
# Epoch 69/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 2.1026 - accuracy: 0.5209
# Epoch 70/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 2.0653 - accuracy: 0.5366
# Epoch 71/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 2.0282 - accuracy: 0.5471
# Epoch 72/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 1.9991 - accuracy: 0.5419
# Epoch 73/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 1.9598 - accuracy: 0.5681
# Epoch 74/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 1.9284 - accuracy: 0.5654
# Epoch 75/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 1.8958 - accuracy: 0.5838
# Epoch 76/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 1.8625 - accuracy: 0.5969
# Epoch 77/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 1.8317 - accuracy: 0.6073
# Epoch 78/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 1.7994 - accuracy: 0.6257
# Epoch 79/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 1.7728 - accuracy: 0.6230
# Epoch 80/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 1.7353 - accuracy: 0.6492
# Epoch 81/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 1.7040 - accuracy: 0.6414
# Epoch 82/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 1.6734 - accuracy: 0.6623
# Epoch 83/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 1.6468 - accuracy: 0.6702
# Epoch 84/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 1.6180 - accuracy: 0.6859
# Epoch 85/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 1.5899 - accuracy: 0.6885
# Epoch 86/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 1.5618 - accuracy: 0.6885
# Epoch 87/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 1.5375 - accuracy: 0.6911
# Epoch 88/1000
# 6/6 [==============================] - 0s 40ms/step - loss: 1.5107 - accuracy: 0.6990
# Epoch 89/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 1.4839 - accuracy: 0.7042
# Epoch 90/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 1.4606 - accuracy: 0.7147
# Epoch 91/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 1.4373 - accuracy: 0.7173
# Epoch 92/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 1.4151 - accuracy: 0.7251
# Epoch 93/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 1.3918 - accuracy: 0.7382
# Epoch 94/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 1.3709 - accuracy: 0.7356
# Epoch 95/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 1.3531 - accuracy: 0.7330
# Epoch 96/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 1.3281 - accuracy: 0.7487
# Epoch 97/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 1.3067 - accuracy: 0.7592
# Epoch 98/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 1.2867 - accuracy: 0.7539
# Epoch 99/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 1.2658 - accuracy: 0.7618
# Epoch 100/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 1.2454 - accuracy: 0.7592
# Epoch 101/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 1.2228 - accuracy: 0.7592
# Epoch 102/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 1.2010 - accuracy: 0.7696
# Epoch 103/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 1.1840 - accuracy: 0.7670
# Epoch 104/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 1.1693 - accuracy: 0.7749
# Epoch 105/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 1.1539 - accuracy: 0.7906
# Epoch 106/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 1.1362 - accuracy: 0.7880
# Epoch 107/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 1.1191 - accuracy: 0.7984
# Epoch 108/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 1.0996 - accuracy: 0.8010
# Epoch 109/1000
# 6/6 [==============================] - 0s 11ms/step - loss: 1.0812 - accuracy: 0.7984
# Epoch 110/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 1.0636 - accuracy: 0.7958
# Epoch 111/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 1.0524 - accuracy: 0.7984
# Epoch 112/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 1.0359 - accuracy: 0.8037
# Epoch 113/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 1.0247 - accuracy: 0.8089
# Epoch 114/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 1.0069 - accuracy: 0.8141
# Epoch 115/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.9893 - accuracy: 0.8115
# Epoch 116/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.9732 - accuracy: 0.8194
# Epoch 117/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.9595 - accuracy: 0.8194
# Epoch 118/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.9444 - accuracy: 0.8246
# Epoch 119/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.9323 - accuracy: 0.8298
# Epoch 120/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.9172 - accuracy: 0.8220
# Epoch 121/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.9042 - accuracy: 0.8246
# Epoch 122/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.8917 - accuracy: 0.8351
# Epoch 123/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.8799 - accuracy: 0.8325
# Epoch 124/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.8687 - accuracy: 0.8325
# Epoch 125/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.8569 - accuracy: 0.8351
# Epoch 126/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.8453 - accuracy: 0.8377
# Epoch 127/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.8335 - accuracy: 0.8429
# Epoch 128/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.8236 - accuracy: 0.8429
# Epoch 129/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.8123 - accuracy: 0.8429
# Epoch 130/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.8017 - accuracy: 0.8403
# Epoch 131/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.7946 - accuracy: 0.8429
# Epoch 132/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.7845 - accuracy: 0.8482
# Epoch 133/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.7778 - accuracy: 0.8560
# Epoch 134/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.7676 - accuracy: 0.8429
# Epoch 135/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 0.7557 - accuracy: 0.8508
# Epoch 136/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.7470 - accuracy: 0.8508
# Epoch 137/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.7390 - accuracy: 0.8482
# Epoch 138/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.7312 - accuracy: 0.8613
# Epoch 139/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.7250 - accuracy: 0.8534
# Epoch 140/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.7139 - accuracy: 0.8560
# Epoch 141/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.7044 - accuracy: 0.8560
# Epoch 142/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.6962 - accuracy: 0.8717
# Epoch 143/1000
# 6/6 [==============================] - 0s 41ms/step - loss: 0.6875 - accuracy: 0.8665
# Epoch 144/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.6809 - accuracy: 0.8717
# Epoch 145/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.6723 - accuracy: 0.8691
# Epoch 146/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.6642 - accuracy: 0.8743
# Epoch 147/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.6564 - accuracy: 0.8717
# Epoch 148/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.6493 - accuracy: 0.8770
# Epoch 149/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.6451 - accuracy: 0.8770
# Epoch 150/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.6342 - accuracy: 0.8796
# Epoch 151/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.6299 - accuracy: 0.8822
# Epoch 152/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.6229 - accuracy: 0.8822
# Epoch 153/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.6173 - accuracy: 0.8796
# Epoch 154/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.6096 - accuracy: 0.8770
# Epoch 155/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.6072 - accuracy: 0.8717
# Epoch 156/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.5983 - accuracy: 0.8770
# Epoch 157/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.5923 - accuracy: 0.8822
# Epoch 158/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.5874 - accuracy: 0.8770
# Epoch 159/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.5823 - accuracy: 0.8848
# Epoch 160/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.5749 - accuracy: 0.8770
# Epoch 161/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.5699 - accuracy: 0.8822
# Epoch 162/1000
# 6/6 [==============================] - 0s 13ms/step - loss: 0.5638 - accuracy: 0.8848
# Epoch 163/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.5599 - accuracy: 0.8796
# Epoch 164/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.5550 - accuracy: 0.8848
# Epoch 165/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.5464 - accuracy: 0.8796
# Epoch 166/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.5400 - accuracy: 0.8874
# Epoch 167/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.5360 - accuracy: 0.8874
# Epoch 168/1000
# 6/6 [==============================] - 0s 11ms/step - loss: 0.5294 - accuracy: 0.8927
# Epoch 169/1000
# 6/6 [==============================] - 0s 60ms/step - loss: 0.5261 - accuracy: 0.8979
# Epoch 170/1000
# 6/6 [==============================] - 0s 12ms/step - loss: 0.5203 - accuracy: 0.8979
# Epoch 171/1000
# 6/6 [==============================] - 0s 12ms/step - loss: 0.5173 - accuracy: 0.8874
# Epoch 172/1000
# 6/6 [==============================] - 0s 12ms/step - loss: 0.5148 - accuracy: 0.8848
# Epoch 173/1000
# 6/6 [==============================] - 0s 12ms/step - loss: 0.5080 - accuracy: 0.8927
# Epoch 174/1000
# 6/6 [==============================] - 0s 12ms/step - loss: 0.5042 - accuracy: 0.8953
# Epoch 175/1000
# 6/6 [==============================] - 0s 16ms/step - loss: 0.4999 - accuracy: 0.8979
# Epoch 176/1000
# 6/6 [==============================] - 0s 11ms/step - loss: 0.4935 - accuracy: 0.9031
# Epoch 177/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 0.4894 - accuracy: 0.9031
# Epoch 178/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 0.4848 - accuracy: 0.9058
# Epoch 179/1000
# 6/6 [==============================] - 0s 12ms/step - loss: 0.4808 - accuracy: 0.9031
# Epoch 180/1000
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4765 - accuracy: 0.9058
# Epoch 181/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 0.4723 - accuracy: 0.9031
# Epoch 182/1000
# 6/6 [==============================] - 0s 11ms/step - loss: 0.4686 - accuracy: 0.9005
# Epoch 183/1000
# 6/6 [==============================] - 0s 57ms/step - loss: 0.4643 - accuracy: 0.9084
# Epoch 184/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.4613 - accuracy: 0.9058
# Epoch 185/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4582 - accuracy: 0.9031
# Epoch 186/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.4538 - accuracy: 0.9058
# Epoch 187/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.4507 - accuracy: 0.9058
# Epoch 188/1000
# 6/6 [==============================] - 0s 39ms/step - loss: 0.4466 - accuracy: 0.9058
# Epoch 189/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4435 - accuracy: 0.9058
# Epoch 190/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4403 - accuracy: 0.9031
# Epoch 191/1000
# 6/6 [==============================] - 0s 74ms/step - loss: 0.4364 - accuracy: 0.9084
# Epoch 192/1000
# 6/6 [==============================] - 0s 11ms/step - loss: 0.4353 - accuracy: 0.8979
# Epoch 193/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4319 - accuracy: 0.9084
# Epoch 194/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4285 - accuracy: 0.9162
# Epoch 195/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4259 - accuracy: 0.9162
# Epoch 196/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4224 - accuracy: 0.9084
# Epoch 197/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4201 - accuracy: 0.9136
# Epoch 198/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4167 - accuracy: 0.9110
# Epoch 199/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4142 - accuracy: 0.9058
# Epoch 200/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4104 - accuracy: 0.9136
# Epoch 201/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4067 - accuracy: 0.9084
# Epoch 202/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4042 - accuracy: 0.9084
# Epoch 203/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4016 - accuracy: 0.9058
# Epoch 204/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3982 - accuracy: 0.9110
# Epoch 205/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3960 - accuracy: 0.9136
# Epoch 206/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3938 - accuracy: 0.9084
# Epoch 207/1000
# 6/6 [==============================] - 0s 39ms/step - loss: 0.3916 - accuracy: 0.9110
# Epoch 208/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.3893 - accuracy: 0.9136
# Epoch 209/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3865 - accuracy: 0.9136
# Epoch 210/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3835 - accuracy: 0.9136
# Epoch 211/1000
# 6/6 [==============================] - 0s 75ms/step - loss: 0.3815 - accuracy: 0.9136
# Epoch 212/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3782 - accuracy: 0.9136
# Epoch 213/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3761 - accuracy: 0.9136
# Epoch 214/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3743 - accuracy: 0.9188
# Epoch 215/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3715 - accuracy: 0.9110
# Epoch 216/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3690 - accuracy: 0.9188
# Epoch 217/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.3673 - accuracy: 0.9136
# Epoch 218/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3653 - accuracy: 0.9188
# Epoch 219/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3630 - accuracy: 0.9110
# Epoch 220/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3617 - accuracy: 0.9162
# Epoch 221/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3593 - accuracy: 0.9188
# Epoch 222/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3571 - accuracy: 0.9162
# Epoch 223/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3546 - accuracy: 0.9188
# Epoch 224/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3526 - accuracy: 0.9084
# Epoch 225/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3513 - accuracy: 0.9136
# Epoch 226/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3505 - accuracy: 0.9162
# Epoch 227/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3474 - accuracy: 0.9162
# Epoch 228/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3456 - accuracy: 0.9084
# Epoch 229/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3440 - accuracy: 0.9162
# Epoch 230/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3413 - accuracy: 0.9162
# Epoch 231/1000
# 6/6 [==============================] - 0s 72ms/step - loss: 0.3387 - accuracy: 0.9136
# Epoch 232/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3374 - accuracy: 0.9136
# Epoch 233/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3348 - accuracy: 0.9215
# Epoch 234/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.3341 - accuracy: 0.9084
# Epoch 235/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3309 - accuracy: 0.9188
# Epoch 236/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3293 - accuracy: 0.9058
# Epoch 237/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3281 - accuracy: 0.9136
# Epoch 238/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3270 - accuracy: 0.9188
# Epoch 239/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3256 - accuracy: 0.9110
# Epoch 240/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3229 - accuracy: 0.9136
# Epoch 241/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3220 - accuracy: 0.9188
# Epoch 242/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3200 - accuracy: 0.9084
# Epoch 243/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3186 - accuracy: 0.9110
# Epoch 244/1000
# 6/6 [==============================] - 0s 13ms/step - loss: 0.3168 - accuracy: 0.9084
# Epoch 245/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3149 - accuracy: 0.9162
# Epoch 246/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3138 - accuracy: 0.9162
# Epoch 247/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3119 - accuracy: 0.9084
# Epoch 248/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.3106 - accuracy: 0.9058
# Epoch 249/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3089 - accuracy: 0.9188
# Epoch 250/1000
# 6/6 [==============================] - 0s 69ms/step - loss: 0.3073 - accuracy: 0.9031
# Epoch 251/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3054 - accuracy: 0.9136
# Epoch 252/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3039 - accuracy: 0.9058
# Epoch 253/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3024 - accuracy: 0.9110
# Epoch 254/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3011 - accuracy: 0.9058
# Epoch 255/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3009 - accuracy: 0.9110
# Epoch 256/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2989 - accuracy: 0.9136
# Epoch 257/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2968 - accuracy: 0.9136
# Epoch 258/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.2961 - accuracy: 0.9110
# Epoch 259/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2939 - accuracy: 0.9136
# Epoch 260/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2931 - accuracy: 0.9110
# Epoch 261/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2914 - accuracy: 0.9084
# Epoch 262/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2898 - accuracy: 0.9162
# Epoch 263/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2883 - accuracy: 0.9084
# Epoch 264/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2875 - accuracy: 0.9136
# Epoch 265/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2861 - accuracy: 0.9162
# Epoch 266/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2850 - accuracy: 0.9188
# Epoch 267/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.2838 - accuracy: 0.9162
# Epoch 268/1000
# 6/6 [==============================] - 1s 104ms/step - loss: 0.2823 - accuracy: 0.9136
# Epoch 269/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.2811 - accuracy: 0.9136
# Epoch 270/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.2802 - accuracy: 0.9188
# Epoch 271/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2797 - accuracy: 0.9162
# Epoch 272/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2785 - accuracy: 0.9084
# Epoch 273/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2772 - accuracy: 0.9136
# Epoch 274/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2761 - accuracy: 0.9162
# Epoch 275/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2750 - accuracy: 0.9110
# Epoch 276/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2738 - accuracy: 0.9162
# Epoch 277/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2733 - accuracy: 0.9162
# Epoch 278/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2717 - accuracy: 0.9136
# Epoch 279/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.2712 - accuracy: 0.9110
# Epoch 280/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2699 - accuracy: 0.9136
# Epoch 281/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2681 - accuracy: 0.9215
# Epoch 282/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2671 - accuracy: 0.9188
# Epoch 283/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2663 - accuracy: 0.9188
# Epoch 284/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2648 - accuracy: 0.9162
# Epoch 285/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2638 - accuracy: 0.9162
# Epoch 286/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2632 - accuracy: 0.9188
# Epoch 287/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 0.2622 - accuracy: 0.9188
# Epoch 288/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 0.2613 - accuracy: 0.9215
# Epoch 289/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2604 - accuracy: 0.9188
# Epoch 290/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2598 - accuracy: 0.9215
# Epoch 291/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2598 - accuracy: 0.9162
# Epoch 292/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2595 - accuracy: 0.9215
# Epoch 293/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2582 - accuracy: 0.9188
# Epoch 294/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2567 - accuracy: 0.9162
# Epoch 295/1000
# 6/6 [==============================] - 0s 11ms/step - loss: 0.2550 - accuracy: 0.9241
# Epoch 296/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2544 - accuracy: 0.9136
# Epoch 297/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 0.2531 - accuracy: 0.9188
# Epoch 298/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2525 - accuracy: 0.9215
# Epoch 299/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2513 - accuracy: 0.9188
# Epoch 300/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.2508 - accuracy: 0.9162
# Epoch 301/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2494 - accuracy: 0.9188
# Epoch 302/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2486 - accuracy: 0.9188
# Epoch 303/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2480 - accuracy: 0.9188
# Epoch 304/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2471 - accuracy: 0.9162
# Epoch 305/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.2467 - accuracy: 0.9188
# Epoch 306/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2457 - accuracy: 0.9215
# Epoch 307/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2450 - accuracy: 0.9215
# Epoch 308/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2442 - accuracy: 0.9136
# Epoch 309/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2434 - accuracy: 0.9058
# Epoch 310/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2422 - accuracy: 0.9162
# Epoch 311/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2415 - accuracy: 0.9136
# Epoch 312/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2416 - accuracy: 0.9058
# Epoch 313/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2404 - accuracy: 0.9162
# Epoch 314/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2400 - accuracy: 0.9162
# Epoch 315/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2386 - accuracy: 0.9215
# Epoch 316/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2385 - accuracy: 0.9188
# Epoch 317/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2379 - accuracy: 0.9215
# Epoch 318/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2369 - accuracy: 0.9162
# Epoch 319/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2362 - accuracy: 0.9215
# Epoch 320/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2360 - accuracy: 0.9162
# Epoch 321/1000
# 6/6 [==============================] - 0s 13ms/step - loss: 0.2345 - accuracy: 0.9162
# Epoch 322/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 0.2338 - accuracy: 0.9267
# Epoch 323/1000
# 6/6 [==============================] - 0s 11ms/step - loss: 0.2334 - accuracy: 0.9162
# Epoch 324/1000
# 6/6 [==============================] - 0s 11ms/step - loss: 0.2332 - accuracy: 0.9188
# Epoch 325/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 0.2320 - accuracy: 0.9241
# Epoch 326/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 0.2312 - accuracy: 0.9162
# Epoch 327/1000
# 6/6 [==============================] - 0s 13ms/step - loss: 0.2308 - accuracy: 0.9215
# Epoch 328/1000
# 6/6 [==============================] - 0s 13ms/step - loss: 0.2305 - accuracy: 0.9188
# Epoch 329/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 0.2305 - accuracy: 0.9136
# Epoch 330/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.2290 - accuracy: 0.9215
# Epoch 331/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 0.2284 - accuracy: 0.9241
# Epoch 332/1000
# 6/6 [==============================] - 0s 11ms/step - loss: 0.2284 - accuracy: 0.9136
# Epoch 333/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 0.2272 - accuracy: 0.9162
# Epoch 334/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 0.2264 - accuracy: 0.9188
# Epoch 335/1000
# 6/6 [==============================] - 0s 11ms/step - loss: 0.2258 - accuracy: 0.9162
# Epoch 336/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 0.2252 - accuracy: 0.9215
# Epoch 337/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.2251 - accuracy: 0.9084
# Epoch 338/1000
# 6/6 [==============================] - 0s 12ms/step - loss: 0.2242 - accuracy: 0.9084
# Epoch 339/1000
# 6/6 [==============================] - 0s 11ms/step - loss: 0.2236 - accuracy: 0.9136
# Epoch 340/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 0.2231 - accuracy: 0.9188
# Epoch 341/1000
# 6/6 [==============================] - 0s 12ms/step - loss: 0.2225 - accuracy: 0.9215
# Epoch 342/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 0.2224 - accuracy: 0.9162
# Epoch 343/1000
# 6/6 [==============================] - 0s 13ms/step - loss: 0.2215 - accuracy: 0.9188
# Epoch 344/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 0.2210 - accuracy: 0.9136
# Epoch 345/1000
# 6/6 [==============================] - 0s 12ms/step - loss: 0.2206 - accuracy: 0.9188
# Epoch 346/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.2197 - accuracy: 0.9215
# Epoch 347/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2189 - accuracy: 0.9241
# Epoch 348/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2188 - accuracy: 0.9136
# Epoch 349/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2184 - accuracy: 0.9136
# Epoch 350/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2180 - accuracy: 0.9188
# Epoch 351/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.2175 - accuracy: 0.9162
# Epoch 352/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2168 - accuracy: 0.9162
# Epoch 353/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.2164 - accuracy: 0.9188
# Epoch 354/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2170 - accuracy: 0.9215
# Epoch 355/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2158 - accuracy: 0.9162
# Epoch 356/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2152 - accuracy: 0.9215
# Epoch 357/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.2145 - accuracy: 0.9162
# Epoch 358/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2146 - accuracy: 0.9215
# Epoch 359/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.2132 - accuracy: 0.9188
# Epoch 360/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2134 - accuracy: 0.9162
# Epoch 361/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2125 - accuracy: 0.9110
# Epoch 362/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2116 - accuracy: 0.9136
# Epoch 363/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2115 - accuracy: 0.9188
# Epoch 364/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2107 - accuracy: 0.9267
# Epoch 365/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2103 - accuracy: 0.9136
# Epoch 366/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2098 - accuracy: 0.9215
# Epoch 367/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2092 - accuracy: 0.9215
# Epoch 368/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2093 - accuracy: 0.9110
# Epoch 369/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2086 - accuracy: 0.9110
# Epoch 370/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2087 - accuracy: 0.9188
# Epoch 371/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.2076 - accuracy: 0.9188
# Epoch 372/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2073 - accuracy: 0.9136
# Epoch 373/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2064 - accuracy: 0.9162
# Epoch 374/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2066 - accuracy: 0.9162
# Epoch 375/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2058 - accuracy: 0.9162
# Epoch 376/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2054 - accuracy: 0.9162
# Epoch 377/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2051 - accuracy: 0.9241
# Epoch 378/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.2057 - accuracy: 0.9241
# Epoch 379/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2052 - accuracy: 0.9136
# Epoch 380/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2038 - accuracy: 0.9188
# Epoch 381/1000
# 6/6 [==============================] - 0s 13ms/step - loss: 0.2042 - accuracy: 0.9162
# Epoch 382/1000
# 6/6 [==============================] - 0s 13ms/step - loss: 0.2032 - accuracy: 0.9162
# Epoch 383/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 0.2026 - accuracy: 0.9188
# Epoch 384/1000
# 6/6 [==============================] - 0s 11ms/step - loss: 0.2025 - accuracy: 0.9162
# Epoch 385/1000
# 6/6 [==============================] - 0s 11ms/step - loss: 0.2025 - accuracy: 0.9058
# Epoch 386/1000
# 6/6 [==============================] - 0s 11ms/step - loss: 0.2030 - accuracy: 0.9084
# Epoch 387/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 0.2018 - accuracy: 0.9162
# Epoch 388/1000
# 6/6 [==============================] - 0s 11ms/step - loss: 0.2016 - accuracy: 0.9031
# Epoch 389/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 0.2012 - accuracy: 0.9188
# Epoch 390/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 0.2002 - accuracy: 0.9188
# Epoch 391/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 0.2001 - accuracy: 0.9215
# Epoch 392/1000
# 6/6 [==============================] - 0s 11ms/step - loss: 0.1994 - accuracy: 0.9110
# Epoch 393/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1994 - accuracy: 0.9136
# Epoch 394/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 0.1987 - accuracy: 0.9188
# Epoch 395/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 0.1981 - accuracy: 0.9136
# Epoch 396/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1980 - accuracy: 0.9215
# Epoch 397/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 0.1975 - accuracy: 0.9241
# Epoch 398/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 0.1971 - accuracy: 0.9136
# Epoch 399/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1969 - accuracy: 0.9215
# Epoch 400/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 0.1968 - accuracy: 0.9084
# Epoch 401/1000
# 6/6 [==============================] - 0s 11ms/step - loss: 0.1961 - accuracy: 0.9188
# Epoch 402/1000
# 6/6 [==============================] - 0s 12ms/step - loss: 0.1959 - accuracy: 0.9188
# Epoch 403/1000
# 6/6 [==============================] - 0s 13ms/step - loss: 0.1955 - accuracy: 0.9136
# Epoch 404/1000
# 6/6 [==============================] - 0s 13ms/step - loss: 0.1956 - accuracy: 0.9215
# Epoch 405/1000
# 6/6 [==============================] - 0s 12ms/step - loss: 0.1950 - accuracy: 0.9136
# Epoch 406/1000
# 6/6 [==============================] - 0s 11ms/step - loss: 0.1946 - accuracy: 0.9188
# Epoch 407/1000
# 6/6 [==============================] - 0s 12ms/step - loss: 0.1940 - accuracy: 0.9188
# Epoch 408/1000
# 6/6 [==============================] - 0s 11ms/step - loss: 0.1939 - accuracy: 0.9110
# Epoch 409/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1937 - accuracy: 0.9215
# Epoch 410/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1934 - accuracy: 0.9215
# Epoch 411/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1928 - accuracy: 0.9267
# Epoch 412/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1923 - accuracy: 0.9267
# Epoch 413/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1920 - accuracy: 0.9215
# Epoch 414/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1920 - accuracy: 0.9241
# Epoch 415/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1913 - accuracy: 0.9267
# Epoch 416/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1912 - accuracy: 0.9215
# Epoch 417/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1914 - accuracy: 0.9293
# Epoch 418/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1908 - accuracy: 0.9241
# Epoch 419/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1905 - accuracy: 0.9215
# Epoch 420/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1901 - accuracy: 0.9188
# Epoch 421/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1900 - accuracy: 0.9241
# Epoch 422/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1897 - accuracy: 0.9241
# Epoch 423/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1891 - accuracy: 0.9215
# Epoch 424/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1891 - accuracy: 0.9162
# Epoch 425/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1890 - accuracy: 0.9188
# Epoch 426/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1884 - accuracy: 0.9215
# Epoch 427/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1884 - accuracy: 0.9136
# Epoch 428/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1881 - accuracy: 0.9241
# Epoch 429/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1878 - accuracy: 0.9162
# Epoch 430/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1878 - accuracy: 0.9188
# Epoch 431/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1873 - accuracy: 0.9188
# Epoch 432/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1869 - accuracy: 0.9215
# Epoch 433/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1867 - accuracy: 0.9110
# Epoch 434/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1864 - accuracy: 0.9188
# Epoch 435/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1860 - accuracy: 0.9215
# Epoch 436/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1861 - accuracy: 0.9188
# Epoch 437/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1863 - accuracy: 0.9110
# Epoch 438/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1853 - accuracy: 0.9241
# Epoch 439/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1853 - accuracy: 0.9188
# Epoch 440/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1850 - accuracy: 0.9136
# Epoch 441/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1847 - accuracy: 0.9267
# Epoch 442/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 0.1843 - accuracy: 0.9188
# Epoch 443/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1847 - accuracy: 0.9215
# Epoch 444/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1841 - accuracy: 0.9241
# Epoch 445/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1837 - accuracy: 0.9267
# Epoch 446/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1833 - accuracy: 0.9162
# Epoch 447/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1829 - accuracy: 0.9241
# Epoch 448/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1825 - accuracy: 0.9215
# Epoch 449/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1823 - accuracy: 0.9215
# Epoch 450/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1828 - accuracy: 0.9215
# Epoch 451/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1820 - accuracy: 0.9162
# Epoch 452/1000
# 6/6 [==============================] - 0s 12ms/step - loss: 0.1821 - accuracy: 0.9215
# Epoch 453/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1815 - accuracy: 0.9267
# Epoch 454/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1816 - accuracy: 0.9188
# Epoch 455/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1813 - accuracy: 0.9215
# Epoch 456/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1809 - accuracy: 0.9267
# Epoch 457/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1808 - accuracy: 0.9267
# Epoch 458/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1807 - accuracy: 0.9215
# Epoch 459/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1804 - accuracy: 0.9241
# Epoch 460/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1799 - accuracy: 0.9215
# Epoch 461/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1798 - accuracy: 0.9162
# Epoch 462/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1795 - accuracy: 0.9215
# Epoch 463/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1793 - accuracy: 0.9293
# Epoch 464/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1792 - accuracy: 0.9188
# Epoch 465/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1789 - accuracy: 0.9110
# Epoch 466/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1789 - accuracy: 0.9267
# Epoch 467/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1784 - accuracy: 0.9215
# Epoch 468/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1787 - accuracy: 0.9162
# Epoch 469/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1785 - accuracy: 0.9267
# Epoch 470/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1782 - accuracy: 0.9241
# Epoch 471/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1786 - accuracy: 0.9136
# Epoch 472/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1775 - accuracy: 0.9188
# Epoch 473/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1774 - accuracy: 0.9136
# Epoch 474/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 0.1772 - accuracy: 0.9188
# Epoch 475/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1768 - accuracy: 0.9215
# Epoch 476/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1766 - accuracy: 0.9188
# Epoch 477/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1767 - accuracy: 0.9188
# Epoch 478/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1760 - accuracy: 0.9215
# Epoch 479/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1761 - accuracy: 0.9162
# Epoch 480/1000
# ...
# Epoch 842/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1424 - accuracy: 0.9058
# Epoch 843/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1418 - accuracy: 0.9215
# Epoch 844/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1421 - accuracy: 0.9215
# Epoch 845/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1417 - accuracy: 0.9188
# Epoch 846/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1416 - accuracy: 0.9215
# Epoch 847/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1417 - accuracy: 0.9215
# Epoch 848/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1419 - accuracy: 0.9215
# Epoch 849/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1421 - accuracy: 0.9162
# Epoch 850/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1422 - accuracy: 0.9215
# Epoch 851/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1418 - accuracy: 0.9215
# Epoch 852/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1417 - accuracy: 0.9215
# Epoch 853/1000
# 6/6 [==============================] - 0s 12ms/step - loss: 0.1415 - accuracy: 0.9241
# Epoch 854/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1417 - accuracy: 0.9162
# Epoch 855/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1416 - accuracy: 0.9215
# Epoch 856/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1420 - accuracy: 0.9215
# Epoch 857/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1416 - accuracy: 0.9293
# Epoch 858/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1412 - accuracy: 0.9241
# Epoch 859/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1419 - accuracy: 0.9241
# Epoch 860/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1417 - accuracy: 0.9162
# Epoch 861/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1415 - accuracy: 0.9136
# Epoch 862/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1416 - accuracy: 0.9136
# Epoch 863/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1412 - accuracy: 0.9241
# Epoch 864/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1413 - accuracy: 0.9058
# Epoch 865/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1412 - accuracy: 0.9136
# Epoch 866/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1410 - accuracy: 0.9162
# Epoch 867/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1414 - accuracy: 0.9084
# Epoch 868/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 0.1414 - accuracy: 0.9110
# Epoch 869/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1409 - accuracy: 0.9188
# Epoch 870/1000
# 6/6 [==============================] - 0s 11ms/step - loss: 0.1411 - accuracy: 0.9215
# Epoch 871/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1407 - accuracy: 0.9215
# Epoch 872/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1411 - accuracy: 0.9136
# Epoch 873/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1412 - accuracy: 0.9188
# Epoch 874/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1409 - accuracy: 0.9241
# Epoch 875/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1412 - accuracy: 0.9162
# Epoch 876/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1413 - accuracy: 0.9136
# Epoch 877/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1410 - accuracy: 0.9188
# Epoch 878/1000
# 6/6 [==============================] - 0s 12ms/step - loss: 0.1409 - accuracy: 0.9162
# Epoch 879/1000
# 6/6 [==============================] - 0s 13ms/step - loss: 0.1405 - accuracy: 0.9215
# Epoch 880/1000
# 6/6 [==============================] - 0s 13ms/step - loss: 0.1410 - accuracy: 0.9162
# Epoch 881/1000
# 6/6 [==============================] - 0s 14ms/step - loss: 0.1408 - accuracy: 0.9241
# Epoch 882/1000
# 6/6 [==============================] - 0s 14ms/step - loss: 0.1410 - accuracy: 0.9162
# Epoch 883/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1409 - accuracy: 0.9162
# Epoch 884/1000
# 6/6 [==============================] - 0s 12ms/step - loss: 0.1407 - accuracy: 0.9162
# Epoch 885/1000
# 6/6 [==============================] - 0s 12ms/step - loss: 0.1403 - accuracy: 0.9215
# Epoch 886/1000
# 6/6 [==============================] - 0s 13ms/step - loss: 0.1405 - accuracy: 0.9215
# Epoch 887/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 0.1405 - accuracy: 0.9136
# Epoch 888/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 0.1403 - accuracy: 0.9215
# Epoch 889/1000
# 6/6 [==============================] - 0s 13ms/step - loss: 0.1406 - accuracy: 0.9188
# Epoch 890/1000
# 6/6 [==============================] - 0s 12ms/step - loss: 0.1405 - accuracy: 0.9188
# Epoch 891/1000
# 6/6 [==============================] - 0s 12ms/step - loss: 0.1408 - accuracy: 0.9215
# Epoch 892/1000
# 6/6 [==============================] - 0s 12ms/step - loss: 0.1407 - accuracy: 0.9136
# Epoch 893/1000
# 6/6 [==============================] - 0s 11ms/step - loss: 0.1405 - accuracy: 0.9188
# Epoch 894/1000
# 6/6 [==============================] - 0s 11ms/step - loss: 0.1399 - accuracy: 0.9293
# Epoch 895/1000
# 6/6 [==============================] - 0s 12ms/step - loss: 0.1407 - accuracy: 0.9136
# Epoch 896/1000
# 6/6 [==============================] - 0s 12ms/step - loss: 0.1399 - accuracy: 0.9267
# Epoch 897/1000
# 6/6 [==============================] - 0s 13ms/step - loss: 0.1403 - accuracy: 0.9136
# Epoch 898/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 0.1404 - accuracy: 0.9110
# Epoch 899/1000
# 6/6 [==============================] - 0s 13ms/step - loss: 0.1398 - accuracy: 0.9241
# Epoch 900/1000
# 6/6 [==============================] - 0s 14ms/step - loss: 0.1398 - accuracy: 0.9188
# Epoch 901/1000
# 6/6 [==============================] - 0s 16ms/step - loss: 0.1400 - accuracy: 0.9136
# Epoch 902/1000
# 6/6 [==============================] - 0s 14ms/step - loss: 0.1400 - accuracy: 0.9215
# Epoch 903/1000
# 6/6 [==============================] - 0s 12ms/step - loss: 0.1400 - accuracy: 0.9136
# Epoch 904/1000
# 6/6 [==============================] - 0s 14ms/step - loss: 0.1399 - accuracy: 0.9188
# Epoch 905/1000
# 6/6 [==============================] - 0s 11ms/step - loss: 0.1401 - accuracy: 0.9136
# Epoch 906/1000
# 6/6 [==============================] - 0s 12ms/step - loss: 0.1397 - accuracy: 0.9215
# Epoch 907/1000
# 6/6 [==============================] - 0s 11ms/step - loss: 0.1398 - accuracy: 0.9136
# Epoch 908/1000
# 6/6 [==============================] - 0s 13ms/step - loss: 0.1398 - accuracy: 0.9215
# Epoch 909/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1397 - accuracy: 0.9188
# Epoch 910/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1399 - accuracy: 0.9188
# Epoch 911/1000
# 6/6 [==============================] - 0s 12ms/step - loss: 0.1398 - accuracy: 0.9241
# Epoch 912/1000
# 6/6 [==============================] - 0s 11ms/step - loss: 0.1396 - accuracy: 0.9241
# Epoch 913/1000
# 6/6 [==============================] - 0s 11ms/step - loss: 0.1398 - accuracy: 0.9188
# Epoch 914/1000
# 6/6 [==============================] - 0s 11ms/step - loss: 0.1399 - accuracy: 0.9267
# Epoch 915/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 0.1395 - accuracy: 0.9215
# Epoch 916/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1398 - accuracy: 0.9162
# Epoch 917/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1397 - accuracy: 0.9188
# Epoch 918/1000
# 6/6 [==============================] - 0s 11ms/step - loss: 0.1398 - accuracy: 0.9215
# Epoch 919/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1398 - accuracy: 0.9188
# Epoch 920/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1391 - accuracy: 0.9293
# Epoch 921/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1394 - accuracy: 0.9136
# Epoch 922/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1393 - accuracy: 0.9188
# Epoch 923/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1395 - accuracy: 0.9162
# Epoch 924/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1395 - accuracy: 0.9188
# Epoch 925/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1396 - accuracy: 0.9136
# Epoch 926/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1392 - accuracy: 0.9241
# Epoch 927/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 0.1394 - accuracy: 0.9188
# Epoch 928/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1392 - accuracy: 0.9162
# Epoch 929/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1390 - accuracy: 0.9215
# Epoch 930/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1390 - accuracy: 0.9162
# Epoch 931/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1389 - accuracy: 0.9241
# Epoch 932/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1395 - accuracy: 0.9110
# Epoch 933/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1391 - accuracy: 0.9188
# Epoch 934/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1390 - accuracy: 0.9188
# Epoch 935/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1389 - accuracy: 0.9188
# Epoch 936/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1392 - accuracy: 0.9110
# Epoch 937/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1392 - accuracy: 0.9136
# Epoch 938/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1390 - accuracy: 0.9162
# Epoch 939/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1390 - accuracy: 0.9162
# Epoch 940/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1393 - accuracy: 0.9215
# Epoch 941/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1388 - accuracy: 0.9241
# Epoch 942/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 0.1387 - accuracy: 0.9110
# Epoch 943/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 0.1390 - accuracy: 0.9162
# Epoch 944/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1389 - accuracy: 0.9162
# Epoch 945/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1385 - accuracy: 0.9188
# Epoch 946/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1390 - accuracy: 0.9162
# Epoch 947/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1389 - accuracy: 0.9162
# Epoch 948/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1390 - accuracy: 0.9110
# Epoch 949/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1383 - accuracy: 0.9084
# Epoch 950/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 0.1383 - accuracy: 0.9241
# Epoch 951/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1385 - accuracy: 0.9188
# Epoch 952/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1389 - accuracy: 0.9136
# Epoch 953/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1386 - accuracy: 0.9215
# Epoch 954/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1379 - accuracy: 0.9267
# Epoch 955/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 0.1385 - accuracy: 0.9162
# Epoch 956/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 0.1383 - accuracy: 0.9162
# Epoch 957/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1383 - accuracy: 0.9188
# Epoch 958/1000
# 6/6 [==============================] - 0s 14ms/step - loss: 0.1392 - accuracy: 0.9162
# Epoch 959/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1384 - accuracy: 0.9215
# Epoch 960/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 0.1384 - accuracy: 0.9188
# Epoch 961/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1382 - accuracy: 0.9188
# Epoch 962/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 0.1383 - accuracy: 0.9215
# Epoch 963/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1380 - accuracy: 0.9241
# Epoch 964/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1383 - accuracy: 0.9162
# Epoch 965/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1382 - accuracy: 0.9136
# Epoch 966/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 0.1381 - accuracy: 0.9215
# Epoch 967/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1382 - accuracy: 0.9215
# Epoch 968/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1384 - accuracy: 0.9110
# Epoch 969/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1381 - accuracy: 0.9215
# Epoch 970/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1380 - accuracy: 0.9241
# Epoch 971/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1383 - accuracy: 0.9136
# Epoch 972/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1379 - accuracy: 0.9188
# Epoch 973/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1378 - accuracy: 0.9241
# Epoch 974/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 0.1381 - accuracy: 0.9136
# Epoch 975/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 0.1377 - accuracy: 0.9215
# Epoch 976/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 0.1382 - accuracy: 0.9058
# Epoch 977/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 0.1380 - accuracy: 0.9215
# Epoch 978/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 0.1378 - accuracy: 0.9215
# Epoch 979/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1382 - accuracy: 0.9188
# Epoch 980/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1377 - accuracy: 0.9241
# Epoch 981/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1376 - accuracy: 0.9267
# Epoch 982/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1380 - accuracy: 0.9188
# Epoch 983/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1380 - accuracy: 0.9162
# Epoch 984/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1378 - accuracy: 0.9215
# Epoch 985/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1377 - accuracy: 0.9215
# Epoch 986/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1378 - accuracy: 0.9162
# Epoch 987/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1377 - accuracy: 0.9241
# Epoch 988/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 0.1373 - accuracy: 0.9215
# Epoch 989/1000
# 6/6 [==============================] - 0s 11ms/step - loss: 0.1378 - accuracy: 0.9162
# Epoch 990/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 0.1376 - accuracy: 0.9188
# Epoch 991/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1376 - accuracy: 0.9241
# Epoch 992/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1376 - accuracy: 0.9136
# Epoch 993/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1375 - accuracy: 0.9136
# Epoch 994/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1373 - accuracy: 0.9188
# Epoch 995/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1376 - accuracy: 0.9267
# Epoch 996/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 0.1373 - accuracy: 0.9241
# Epoch 997/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1371 - accuracy: 0.9267
# Epoch 998/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1376 - accuracy: 0.9162
# Epoch 999/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1372 - accuracy: 0.9241
# Epoch 1000/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1369 - accuracy: 0.9267

# %% [markdown]
# # Q9. 학습된 모델을 이용하여, '나'뒤에 생성될 확률이 가장 높은 3개 단어를 출력하시오.
#
# 1. first_word = ['나'] 을 활용한다.
# 1. 인풋은 똑같은 전처리 과정을 겪어야 한다. (단, 문장 길이는 max_len -1 일것이다. )
# 2. 아웃풋은, 가장 출력값이 큰 3개의 index를 찾아낼 수 있어야 한다.
#     * np.argsort를 활용해볼 것
# 3. 아웃풋의 index가 정확히 어떤 단어를 가리키는지, 토크나이저의 index_word를 활용하여 복원한다.
# 4. 이후에 나올 단어 3개와, 확률을 print를 이용하여 같이 출력한다.

# %%
####################
## Your Code here ##
####################

first_word = ['나']
temp = tokenizer.texts_to_sequences(first_word)
temp = pad_sequences(temp, maxlen=max_len - 1, padding='pre')

y_pred = model.predict(temp)

top3_idx = np.argsort(y_pred)[:, -3:].reshape(-1)[::-1]
top3_probs = y_pred[:, top3_idx].reshape(-1)

for i in range(3):
    word = tokenizer.index_word[top3_idx[i]]
    prob = top3_probs[i]
    print(f'{word} : {prob * 100:.2f}')
# Out:
# 1/1 [==============================] - 0s 23ms/step
# 추억 : 40.35
# 사랑 : 38.91
# 홀로 : 18.71

# %% [markdown]
# # Q10. 위의 Q9에서 두번째로 확률이 높은 단어를 골라 문장을 구성한 뒤, 다음에 올 단어로 가장 확률이 높은 3 단어를 출력하시오.
#
# 1. 만일, 가장 확률 높은 단어가 '추억'이었다면, words = '나 추억' 을 활용한다.
# 1. 확률과 단어를 같이 출력한다.
# 2. 기본적으로는 위 Q9번과 동일하게 푼다.

# %%
####################
## Your Code here ##
####################

first_word = ['나 추억']
temp = tokenizer.texts_to_sequences(first_word)
temp = pad_sequences(temp, maxlen=max_len - 1, padding='pre')

y_pred = model.predict(temp)

top3_idx = np.argsort(y_pred)[:, -3:].reshape(-1)[::-1]
top3_probs = y_pred[:, top3_idx].reshape(-1)

for i in range(3):
    word = tokenizer.index_word[top3_idx[i]]
    prob = top3_probs[i]
    print(f'{word} : {prob * 100:.2f}')
# Out:
# 1/1 [==============================] - 0s 23ms/step
# 한다면 : 99.45
# 않다면 : 0.18
# 너 : 0.12

# %% [markdown]
# # Q11. 9번,10번 문항을 참고하여, 다음의 기능을 하는 함수를 제작한다.
#
# * 편의를 위해, 외부에 선언된 변수를 활용해도 좋다.
# * 인풋 : 사용할 첫 단어, 반복 예측 수
# * 내부 : 매번 가장 확률 높은 단어만 선택한다.
# * 아웃풋 : 완성된 문장.
# * 예시 :
# ```
# jaksa("나", 4 )
# >> "나 추억 한다면 힘차게 걸으리라"
# ```
# * 실제로 노래 가사에 사용된 여러 단어를 넣어 테스트해보자.

# %%
####################
## Your Code here ##
####################
def jaksa(first_word, n):
    first_word = [first_word]
    for i in range(n):
        temp = tokenizer.texts_to_sequences(first_word)
        temp = pad_sequences(temp, maxlen=max_len - 1, padding='pre')

        y_pred = model.predict(temp, verbose=0)
        word = tokenizer.index_word[np.argmax(y_pred)]
        first_word.append(word)
        first_word = [' '.join(first_word)]
    return first_word[0]

# %%
#######################
## Your testing here ##
#######################

jaksa("나", 4)
# Out:
# '나 추억 한다면 힘차게 걸으리라'

# %% [markdown]
# # (+Optional)Q12. Q11번 함수를 개량하여 다듬는다.
#
# * 인풋 : 사용할 첫 단어, 반복 예측 수, 사용할 모델, 사용할 tokenizer
# * 내부 : 모든 예측 중 하나를 확률에 맞추어 sampling 한다.
#     * np.random.choice 이용. 만일 '바람'일 확률이 80%라면, 100번에 80번 정도는 바람이, 20번 정도는 다른 단어가 선택될 것이다.
# * 아웃풋 : 완성된 문장.
# * 반복 예측 수 : 7이상이면 다음의 문구를 출력하고 함수 동작을 종료한다.
#     * "6이하의 반복예측만 가능합니다."
# * 예시 :
# ```
# jaksa("나", 4, tk, model )
# >> "나 추억 한다면 힘차게 걸으리라"
# jaksa("나", 4, tk, model )
# >> "나 사랑 했다면 미소 를"
# ```

# %%
####################
## Your Code here ##
####################
def jaksa(first_word, n, tk, model):
    if n >= 7:
        print('6이하의 반복예측만 가능합니다.')
        return
    first_word = [first_word]
    for i in range(n):
        temp = tk.texts_to_sequences(first_word)
        temp = pad_sequences(temp, maxlen=max_len - 1, padding='pre')

        y_pred = model.predict(temp, verbose=0)

        top3_idx = np.argsort(y_pred)[:, -3:].reshape(-1)[::-1]
        top3_probs = y_pred[:, top3_idx].reshape(-1)
        idx = np.random.choice(top3_idx, p=(top3_probs + ((1 - top3_probs.sum()) / 3))) # 확률적으로 top3 에서 index 뽑기
        word = tk.index_word[idx]
        first_word.append(word)
        first_word = [' '.join(first_word)]
    return first_word[0]

# %%
#######################
## Your testing here ##
#######################

jaksa("나", 4, tokenizer, model)
# Out:
# '나 사랑 했다면 미소 를'

# %%
jaksa("나", 4, tokenizer, model)
# Out:
# '나 추억 한다면 힘차게 걸으리라'

# %%
jaksa("나", 4, tokenizer, model)
# Out:
# '나 홀로 잠들어 해 아프다'

# %%
jaksa("그", 4, tokenizer, model)
# Out:
# '그 영원한 약속 들 을'

# %%
jaksa("그", 4, tokenizer, model)
# Out:
# '그 바 래 진 기억'
