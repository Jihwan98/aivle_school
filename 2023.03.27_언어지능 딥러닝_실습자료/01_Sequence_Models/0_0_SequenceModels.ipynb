# %% [markdown]
# # Sequence Models & How to use them
#
# **학습목표**
# 1. RNN, LSTM, GRU의 구조를 이해한다.
# 2. 위 모델을 사용하기 위한 데이터 구조를 이해한다.
# 3. 위 모든 내용을 코딩할 수 있다.
#
# -----------------
# * Thanks to : 한기영 대표님 @ Data Insight

# %% [markdown]
# ## 1.환경 및 데이터 준비

# %% [markdown]
# ### Import Packages

# %%
#라이브러리들을 불러오자.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.utils import plot_model
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ### Data Loading

# %%
data = pd.read_csv('https://raw.githubusercontent.com/DA4BAM/dataset/master/temperature.csv')
data.head(10)
# Out:
#    year  week   AvgTemp
# 0  2010     1 -3.000000
# 1  2010     2 -7.500000
# 2  2010     3 -7.900000
# 3  2010     4 -2.357143
# 4  2010     5 -3.342857
# 5  2010     6 -1.800000
# 6  2010     7 -0.314286
# 7  2010     8 -2.142857
# 8  2010     9  4.400000
# 9  2010    10  7.057143

# %%
data.tail()
# Out:
#      year  week   AvgTemp
# 260  2014    49  8.100000
# 261  2014    50 -4.357143
# 262  2014    51 -2.142857
# 263  2014    52 -5.542857
# 264  2014    53 -0.728571

# %% [markdown]
# ## 2.데이터 이해

# %% [markdown]
# ### 탐색하기

# %% [markdown]
# 온도의 흐름(trend)을 살펴봅시다.

# %%
plt.figure(figsize=(12, 6))
plt.plot(data.AvgTemp)
plt.show()

# %% [markdown]
# ##3.데이터 준비

# %% [markdown]
# ### 불필요한 데이터 정리

# %%
data = data.drop(['year','week'], axis=1)
data.head()
# Out:
#     AvgTemp
# 0 -3.000000
# 1 -7.500000
# 2 -7.900000
# 3 -2.357143
# 4 -3.342857

# %% [markdown]
# ## 4.Sequence 데이터 구조로 만들기

# %% [markdown]
# 내일의 기온을 예측 하려면?

# %%
data = data.values

# %%
data.shape
# Out:
# (265, 1)

# %%
# 여기에 의미있는 기간(timestep을 지정해 봅시다.)
timestep = 21    # 한 번에 21주씩 고려하자

# x의 데이터 구조를 3차원으로 만들어줘야 합니다.
x = np.array([data[i : i + timestep] for i in range( len(data) - timestep ) ])
y = np.array([data[i + timestep, -1] for i in range( len(data) - timestep ) ])

x_train, x_val, x_test = x[:160], x[160:200], x[200:]
y_train, y_val, y_test = y[:160], y[160:200], y[200:]

print(x.shape, y.shape)
print('-------------------------------')
print(x_train.shape, y_train.shape)
print(x_val.shape, y_val.shape)
print(x_test.shape, y_test.shape)
print('-------------------------------')
print('[ # , timestep, feature수 ] <-- 데이터의 구조 : ')
# Out:
# (244, 21, 1) (244,)
# -------------------------------
# (160, 21, 1) (160,)
# (40, 21, 1) (40,)
# (44, 21, 1) (44,)
# -------------------------------
# [ # , timestep, feature수 ] <-- 데이터의 구조 :

# %% [markdown]
# 데이터의 구조 : [n, timestep, feature수]

# %% [markdown]
# ## 5.RNN 모델링

# %% [markdown]
# ### [실습]무작정 RNN 모델링 수행해보기

# %%
# 1.세션클리어
keras.backend.clear_session()

# 2.Sequential 모델 선언하기
model = keras.models.Sequential()

# 3. 레이어 쌓기 SimpleRNN의 default activation은 'tanh' 입니다.
# input_shape = [timestep, feature수]
# simplernn의 히든스테이트 노드는 16개로 작성해 봅시다.

model.add(keras.layers.Input(shape=(21, 1)))
model.add(keras.layers.SimpleRNN( 16, activation='tanh', return_sequences=False) )
model.add(keras.layers.Dense( 1 ))

# compile
model.compile(loss='mae', # 'mse'대비, '급격한 학습을 막는데' 종종 사용이 됨.
              optimizer='adam')

# 학습
history = model.fit( x_train , y_train  , epochs = 30 , validation_data=(x_val, y_val))
# Out:
# Epoch 1/30
# 5/5 [==============================] - 2s 126ms/step - loss: 13.6464 - val_loss: 14.4169
# Epoch 2/30
# 5/5 [==============================] - 0s 23ms/step - loss: 13.5009 - val_loss: 14.2940
# Epoch 3/30
# 5/5 [==============================] - 0s 20ms/step - loss: 13.3561 - val_loss: 14.1620
# Epoch 4/30
# 5/5 [==============================] - 0s 19ms/step - loss: 13.2000 - val_loss: 14.0271
# Epoch 5/30
# 5/5 [==============================] - 0s 22ms/step - loss: 13.0516 - val_loss: 13.8924
# Epoch 6/30
# 5/5 [==============================] - 0s 21ms/step - loss: 12.9109 - val_loss: 13.7614
# Epoch 7/30
# 5/5 [==============================] - 0s 25ms/step - loss: 12.7695 - val_loss: 13.6361
# Epoch 8/30
# 5/5 [==============================] - 0s 23ms/step - loss: 12.6382 - val_loss: 13.5164
# Epoch 9/30
# 5/5 [==============================] - 0s 29ms/step - loss: 12.5091 - val_loss: 13.4114
# Epoch 10/30
# 5/5 [==============================] - 0s 23ms/step - loss: 12.3982 - val_loss: 13.3173
# Epoch 11/30
# 5/5 [==============================] - 0s 25ms/step - loss: 12.2886 - val_loss: 13.2320
# Epoch 12/30
# 5/5 [==============================] - 0s 23ms/step - loss: 12.1899 - val_loss: 13.1508
# Epoch 13/30
# 5/5 [==============================] - 0s 23ms/step - loss: 12.0937 - val_loss: 13.0728
# Epoch 14/30
# 5/5 [==============================] - 0s 26ms/step - loss: 11.9987 - val_loss: 12.9947
# Epoch 15/30
# 5/5 [==============================] - 0s 19ms/step - loss: 11.9016 - val_loss: 12.9165
# Epoch 16/30
# 5/5 [==============================] - 0s 22ms/step - loss: 11.8026 - val_loss: 12.8337
# Epoch 17/30
# 5/5 [==============================] - 0s 28ms/step - loss: 11.7016 - val_loss: 12.7479
# Epoch 18/30
# 5/5 [==============================] - 0s 21ms/step - loss: 11.6000 - val_loss: 12.6598
# Epoch 19/30
# 5/5 [==============================] - 0s 24ms/step - loss: 11.4978 - val_loss: 12.5727
# Epoch 20/30
# 5/5 [==============================] - 0s 26ms/step - loss: 11.3962 - val_loss: 12.4900
# Epoch 21/30
# 5/5 [==============================] - 0s 38ms/step - loss: 11.3040 - val_loss: 12.4122
# Epoch 22/30
# 5/5 [==============================] - 0s 25ms/step - loss: 11.2160 - val_loss: 12.3391
# Epoch 23/30
# 5/5 [==============================] - 0s 23ms/step - loss: 11.1325 - val_loss: 12.2699
# Epoch 24/30
# 5/5 [==============================] - 0s 26ms/step - loss: 11.0493 - val_loss: 12.2053
# Epoch 25/30
# 5/5 [==============================] - 0s 24ms/step - loss: 10.9701 - val_loss: 12.1442
# Epoch 26/30
# 5/5 [==============================] - 0s 28ms/step - loss: 10.8903 - val_loss: 12.0863
# Epoch 27/30
# 5/5 [==============================] - 0s 19ms/step - loss: 10.8144 - val_loss: 12.0279
# Epoch 28/30
# 5/5 [==============================] - 0s 26ms/step - loss: 10.7342 - val_loss: 11.9678
# Epoch 29/30
# 5/5 [==============================] - 0s 23ms/step - loss: 10.6559 - val_loss: 11.9035
# Epoch 30/30
# 5/5 [==============================] - 0s 26ms/step - loss: 10.5725 - val_loss: 11.8361

# %%
# 학습 곡선을 그려봅시다.
plt.plot(history.history["loss"], label = 'train')
plt.plot(history.history["val_loss"], label = 'valid')
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_squared_error as MSE

# %%
# Q1. 테스트 셋에서의 RMSE를 출력하여라.
y_pred = model.predict(x_test)
print(MSE(y_test, y_pred) ** 0.5)
# Out:
# 2/2 [==============================] - 0s 12ms/step
# 14.818035875406789

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 16)                288
#
#  dense (Dense)               (None, 1)                 17
#
# =================================================================
# Total params: 305
# Trainable params: 305
# Non-trainable params: 0
# _________________________________________________________________

# %%
plot_model(model, show_shapes=True)

# %% [markdown]
# ### More Exercises
#
# 1. 적절한 인풋 레이어를 구성할 것
# 2. 첫번째 히든레이어 : SimpleRNN
#     * 히든스테이트 노드 16개, return_sequences=True
# 3. 두번째 히든레이어 : SimpleRNN
#     * 히든스테이트 노드 32개, return_sequences=True
# 4. 플래튼
# 5. 회귀를 위한 적절한 아웃풋 레이어

# %%
x_train.shape, y_train.shape
# Out:
# ((160, 21, 1), (160,))

# %%
####################
## Your Code Here ##
####################

keras.backend.clear_session()

input_layer = keras.layers.Input(shape=(21, 1))
hl = keras.layers.SimpleRNN(16, return_sequences=True)(input_layer)
hl = keras.layers.SimpleRNN(32, return_sequences=True)(hl)
hl = keras.layers.Flatten()(hl)
output_layer = keras.layers.Dense(1)(hl)

model = keras.models.Model(input_layer, output_layer)

model.compile(loss='mae', optimizer='adam')

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 21, 1)]           0
#
#  simple_rnn (SimpleRNN)      (None, 21, 16)            288
#
#  simple_rnn_1 (SimpleRNN)    (None, 21, 32)            1568
#
#  flatten (Flatten)           (None, 672)               0
#
#  dense (Dense)               (None, 1)                 673
#
# =================================================================
# Total params: 2,529
# Trainable params: 2,529
# Non-trainable params: 0
# _________________________________________________________________

# %%
## 학습도 시킬 것
history = model.fit(x_train, y_train, validation_data=(x_val, y_val), epochs=30)
# Out:
# Epoch 1/30
# 5/5 [==============================] - 3s 151ms/step - loss: 12.3716 - val_loss: 12.0997
# Epoch 2/30
# 5/5 [==============================] - 0s 43ms/step - loss: 11.4693 - val_loss: 11.0797
# Epoch 3/30
# 5/5 [==============================] - 0s 32ms/step - loss: 10.5404 - val_loss: 10.2997
# Epoch 4/30
# 5/5 [==============================] - 0s 41ms/step - loss: 9.8248 - val_loss: 9.6243
# Epoch 5/30
# 5/5 [==============================] - 0s 35ms/step - loss: 9.1574 - val_loss: 9.1254
# Epoch 6/30
# 5/5 [==============================] - 0s 33ms/step - loss: 8.4777 - val_loss: 8.7782
# Epoch 7/30
# 5/5 [==============================] - 0s 37ms/step - loss: 7.8682 - val_loss: 8.4001
# Epoch 8/30
# 5/5 [==============================] - 0s 34ms/step - loss: 7.3508 - val_loss: 8.0300
# Epoch 9/30
# 5/5 [==============================] - 0s 32ms/step - loss: 6.7938 - val_loss: 7.7424
# Epoch 10/30
# 5/5 [==============================] - 0s 30ms/step - loss: 6.4122 - val_loss: 7.5419
# Epoch 11/30
# 5/5 [==============================] - 0s 25ms/step - loss: 6.1548 - val_loss: 7.1917
# Epoch 12/30
# 5/5 [==============================] - 0s 16ms/step - loss: 5.8634 - val_loss: 6.8516
# Epoch 13/30
# 5/5 [==============================] - 0s 19ms/step - loss: 5.6935 - val_loss: 6.5923
# Epoch 14/30
# 5/5 [==============================] - 0s 18ms/step - loss: 5.5230 - val_loss: 6.3656
# Epoch 15/30
# 5/5 [==============================] - 0s 16ms/step - loss: 5.3652 - val_loss: 6.1263
# Epoch 16/30
# 5/5 [==============================] - 0s 18ms/step - loss: 5.1787 - val_loss: 5.9273
# Epoch 17/30
# 5/5 [==============================] - 0s 16ms/step - loss: 5.0468 - val_loss: 5.7379
# Epoch 18/30
# 5/5 [==============================] - 0s 15ms/step - loss: 4.9140 - val_loss: 5.6066
# Epoch 19/30
# 5/5 [==============================] - 0s 19ms/step - loss: 4.7125 - val_loss: 5.3065
# Epoch 20/30
# 5/5 [==============================] - 0s 21ms/step - loss: 4.5565 - val_loss: 5.2630
# Epoch 21/30
# 5/5 [==============================] - 0s 19ms/step - loss: 4.3649 - val_loss: 4.9629
# Epoch 22/30
# 5/5 [==============================] - 0s 21ms/step - loss: 4.0895 - val_loss: 4.8829
# Epoch 23/30
# 5/5 [==============================] - 0s 20ms/step - loss: 3.8668 - val_loss: 4.7006
# Epoch 24/30
# 5/5 [==============================] - 0s 22ms/step - loss: 3.6581 - val_loss: 4.3786
# Epoch 25/30
# 5/5 [==============================] - 0s 21ms/step - loss: 3.3908 - val_loss: 4.1417
# Epoch 26/30
# 5/5 [==============================] - 0s 18ms/step - loss: 3.1651 - val_loss: 3.7949
# Epoch 27/30
# 5/5 [==============================] - 0s 18ms/step - loss: 2.8956 - val_loss: 3.4584
# Epoch 28/30
# 5/5 [==============================] - 0s 19ms/step - loss: 2.6542 - val_loss: 3.1596
# Epoch 29/30
# 5/5 [==============================] - 0s 22ms/step - loss: 2.3652 - val_loss: 2.9247
# Epoch 30/30
# 5/5 [==============================] - 0s 22ms/step - loss: 2.1166 - val_loss: 2.5660

# %%
# 학습 곡선을 그려봅시다.
plt.plot(history.history["loss"], label = 'train')
plt.plot(history.history["val_loss"], label = 'valid')
plt.legend()
plt.show()

# %%
# Q1. 테스트 셋에서의 RMSE를 출력하여라.
y_pred = model.predict(x_test)
print(f'RMSE : {MSE(y_test, y_pred)}')
# Out:
# 2/2 [==============================] - 0s 8ms/step
# RMSE : 8.140580216743997

# %% [markdown]
# ## 6.LSTM 모델링
#
# 1. 적절한 인풋 레이어를 구성할 것
# 2. 첫번째 히든레이어 : LSTM
#     * 히든스테이트 노드 16개, return_sequences=True
# 3. 두번째 히든레이어 : LSTM
#     * 히든스테이트 노드 32개, return_sequences=True
# 4. 플래튼
# 5. 회귀를 위한 적절한 아웃풋 레이어

# %%
####################
## Your Code Here ##
####################

# %%
## 학습도 시킬 것

# %%
# Q1. 테스트 셋에서의 RMSE를 출력하여라.

# %% [markdown]
# ## 7.GRU 모델링
#
#
# 1. 적절한 인풋 레이어를 구성할 것
# 2. 첫번째 히든레이어 : GRU
#     * 히든스테이트 노드 24개, return_sequences=True
# 3. 두번째 히든레이어 : GRU
#     * 히든스테이트 노드 32개
# 4. 회귀를 위한 적절한 아웃풋 레이어

# %%
####################
## Your Code Here ##
####################

# %%
## 학습도 시킬 것

# %%
# Q1. 테스트 셋에서의 RMSE를 출력하여라.
