# %% [markdown]
# # 1일차 Review : 같은 문제 다시 풀어보기
# ---
# - 학습은 10번만!

# %%
from sklearn.datasets import load_breast_cancer

# %%
cancer = load_breast_cancer()

# %%
x = cancer.data
y = cancer.target

# %%
x.shape, y.shape
# Out:
# ((569, 30), (569,))

# %%
##########################
# train set/ test set 분리
##########################
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=2023)

# %%
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((455, 30), (455,), (114, 30), (114,))

# %%
#####################
# 라이브러리 불러오기
#####################
import tensorflow as tf
from tensorflow import keras

# %%
########
# 모델링
########
# 1. 세션 초기화
keras.backend.clear_session()

# 2. 모델 생성
model = keras.models.Sequential()

# 3. 모델 쌓기
model.add( keras.layers.Input(shape=(30, )) )
model.add( keras.layers.Dense(1, activation='sigmoid') )

# 4. 모델 컴파일
model.compile(loss='binary_crossentropy', metrics=['accuracy'], optimizer='adam')

# 모델 summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1)                 31
#
# =================================================================
# Total params: 31
# Trainable params: 31
# Non-trainable params: 0
# _________________________________________________________________

# %%
###########
# 모델 학습
###########
model.fit(x_train, y_train, epochs=10)
# Out:
# Epoch 1/10
# 15/15 [==============================] - 1s 3ms/step - loss: 27.2641 - accuracy: 0.3714
# Epoch 2/10
# 15/15 [==============================] - 0s 2ms/step - loss: 15.3901 - accuracy: 0.3956
# Epoch 3/10
# 15/15 [==============================] - 0s 2ms/step - loss: 5.3527 - accuracy: 0.5978
# Epoch 4/10
# 15/15 [==============================] - 0s 3ms/step - loss: 1.7940 - accuracy: 0.8286
# Epoch 5/10
# 15/15 [==============================] - 0s 3ms/step - loss: 1.4333 - accuracy: 0.8813
# Epoch 6/10
# 15/15 [==============================] - 0s 3ms/step - loss: 1.4717 - accuracy: 0.8923
# Epoch 7/10
# 15/15 [==============================] - 0s 3ms/step - loss: 1.4428 - accuracy: 0.8901
# Epoch 8/10
# 15/15 [==============================] - 0s 3ms/step - loss: 1.4225 - accuracy: 0.8813
# Epoch 9/10
# 15/15 [==============================] - 0s 3ms/step - loss: 1.4174 - accuracy: 0.8769
# Epoch 10/10
# 15/15 [==============================] - 0s 2ms/step - loss: 1.4157 - accuracy: 0.8747

# %%
###########
# 모델 예측
###########
y_pred = model.predict(x_test)
print(y_pred[:5])
print(y_test[:5])
# Out:
# 4/4 [==============================] - 0s 3ms/step
# [[2.0098371e-18]
#  [1.8062734e-03]
#  [9.5310491e-01]
#  [3.5238153e-30]
#  [0.0000000e+00]]
# [0 0 1 0 0]

# %% [markdown]
# # 히든 레이어 추가하여 모델링!
# ---
# - 조건
#     - 히든 레이어 2개를 추가하여 다시 모델링!
#     - 히든 레이어 노드 수 : 32
#     - 히든 레이어 activation = 'relu'

# %%
########
# 모델링
########
# 1. 세션 초기화
keras.backend.clear_session()

# 2. 모델 생성
model = keras.models.Sequential()

# 3. 모델 쌓기
model.add( keras.layers.Input(shape=(30,)) )
model.add( keras.layers.Dense(32, activation='relu') )
model.add( keras.layers.Dense(32, activation='relu') )
model.add( keras.layers.Dense(1, activation='sigmoid') )

# 4. 모델 컴파일
model.compile(loss='binary_crossentropy', metrics=['accuracy'], optimizer='adam')

# 모델 summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 32)                992
#
#  dense_1 (Dense)             (None, 32)                1056
#
#  dense_2 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 2,081
# Trainable params: 2,081
# Non-trainable params: 0
# _________________________________________________________________

# %%
###########
# 모델 학습
###########
model.fit(x_train, y_train, epochs=10)
# Out:
# Epoch 1/10
# 15/15 [==============================] - 1s 2ms/step - loss: 12.6029 - accuracy: 0.5143
# Epoch 2/10
# 15/15 [==============================] - 0s 2ms/step - loss: 1.7839 - accuracy: 0.6901
# Epoch 3/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.8969 - accuracy: 0.8242
# Epoch 4/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.8056 - accuracy: 0.8945
# Epoch 5/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6566 - accuracy: 0.8747
# Epoch 6/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4736 - accuracy: 0.8879
# Epoch 7/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.3963 - accuracy: 0.8967
# Epoch 8/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.3320 - accuracy: 0.8945
# Epoch 9/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.3138 - accuracy: 0.8945
# Epoch 10/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2780 - accuracy: 0.9143

# %%
###########
# 모델 예측
###########
y_pred = model.predict(x_test)
print(y_pred[:5])
print(y_test[:5])
# Out:
# 4/4 [==============================] - 0s 2ms/step
# [[3.0960410e-04]
#  [9.1537660e-01]
#  [8.8744491e-01]
#  [1.5279502e-08]
#  [1.4642662e-17]]
# [0 0 1 0 0]
