# %% [markdown]
# # **미니프로젝트 4차 1대1 문의 내용 유형 분류기**
# # 단계1 : 데이터 탐색
#
# ### 문제 정의
# > 1:1 문의 내용 분류 문제<br>
# > 1. 문의 내용 분석
# > 2. 문의 내용 분류 모델 성능 평가
# ### 학습 데이터
# > * 1:1 문의 내용 데이터 : train.csv
#
# ### 변수 소개
# > * text : 문의 내용
# > * label : 문의 유형
#
# ### References
# > * 한국어 처리
# >> * [konlpy - 한국어 처리 라이브러리](https://konlpy.org/ko/latest/)
# >> * [한국어 품사 태그 비교표](https://docs.google.com/spreadsheets/d/1OGAjUvalBuX-oZvZ_-9tEfYD2gQe7hTGsgUpiiBSXI8/edit#gid=0)
# >> * [한국어 품사 태깅 성능 비교](https://konlpy.org/ko/latest/morph/#comparison-between-pos-tagging-classes)
# >> * [한국어 시스템 사전](https://konlpy.org/ko/latest/data/#corpora)
#
# > * 자연어 처리
# >> * [NLTK](https://www.nltk.org/book/)
# >> * [gensim](https://radimrehurek.com/gensim/)
# >> * [Google guide](https://developers.google.com/machine-learning/guides/text-classification/step-2)
# >> * [WordCloud](https://amueller.github.io/word_cloud/)

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 23 not upgraded.
# Need to get 9,599 kB of archives.
# After this operation, 29.6 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal/universe amd64 fonts-nanum all 20180306-3 [9,599 kB]
# Fetched 9,599 kB in 1s (10.5 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 128288 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20180306-3_all.deb ...
# Unpacking fonts-nanum (20180306-3) ...
# Setting up fonts-nanum (20180306-3) ...
# Processing triggers for fontconfig (2.13.1-2ubuntu3) ...
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 10 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# /usr/share/fonts/truetype/liberation: skipping, looped directory detected
# /usr/share/fonts/truetype/nanum: skipping, looped directory detected
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded

# %%
import matplotlib.pyplot as plt

plt.rc('font', family='NanumBarunGothic')

# %% [markdown]
# ## 1. 개발 환경 설정

# %% [markdown]
# * 세부 요구사항
#   - 기본적으로 필요한 라이브러리를 import 하도록 코드가 작성되어 있습니다.
#   - 필요하다고 판단되는 라이브러리를 추가하세요.
#   - konlpy, mecab 설치 후 형태소 분석 함수 생성
#   - mecab 설치할 때 윈도우 pc에서 설치는 다른 방법으로 진행
#   - 윈도우 환경일 경우 KoNLPy의 라이브러리 설치가 제대로 이루어지지 않을 수 있습니다
#   - 윈도우 설치를 위한 참고 링크
#     - https://liveyourit.tistory.com/56

# %% [markdown]
# ### 1-1. 라이브러리 설치

# %%
# 필요 라이브러리부터 설치할께요.
# !pip install konlpy pandas seaborn gensim wordcloud python-mecab-ko wget
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting konlpy
#   Downloading konlpy-0.6.0-py2.py3-none-any.whl (19.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.4/19.4 MB 50.2 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (1.4.4)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.9/dist-packages (0.12.2)
# Requirement already satisfied: gensim in /usr/local/lib/python3.9/dist-packages (4.3.1)
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.9/dist-packages (1.8.2.2)
# Collecting python-mecab-ko
#   Downloading python_mecab_ko-1.3.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (575 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 575.6/575.6 KB 49.4 MB/s eta 0:00:00
# Collecting wget
#   Downloading wget-3.2.zip (10 kB)
#   Preparing metadata (setup.py) ... done
# Collecting JPype1>=0.7.0
#   Downloading JPype1-1.4.1-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (465 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 465.3/465.3 KB 37.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.9/dist-packages (from konlpy) (1.22.4)
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.9/dist-packages (from konlpy) (4.9.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas) (2022.7.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in /usr/local/lib/python3.9/dist-packages (from seaborn) (3.7.1)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.9/dist-packages (from gensim) (1.10.1)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.9/dist-packages (from gensim) (6.3.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.9/dist-packages (from wordcloud) (8.4.0)
# Collecting python-mecab-ko-dic
#   Downloading python_mecab_ko_dic-2.1.1.post2-py3-none-any.whl (34.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.5/34.5 MB 12.9 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from JPype1>=0.7.0->konlpy) (23.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.7)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.39.3)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (5.12.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.1->seaborn) (3.15.0)
# Building wheels for collected packages: wget
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9676 sha256=a95a124eb23b68b1f757a0b559440267bfd0ded38db19d16f6659f32e21c75fc
#   Stored in directory: /root/.cache/pip/wheels/04/5f/3e/46cc37c5d698415694d83f607f833f83f0149e49b3af9d0f38
# Successfully built wget
# Installing collected packages: wget, python-mecab-ko-dic, python-mecab-ko, JPype1, konlpy
# Successfully installed JPype1-1.4.1 konlpy-0.6.0 python-mecab-ko-1.3.3 python-mecab-ko-dic-2.1.1.post2 wget-3.2

# %% [markdown]
# ### 1-2. 라이브러리 import

# %%
from mecab import MeCab
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from IPython.display import display
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
from wordcloud import WordCloud
from collections import Counter
import wget, os

# %% [markdown]
# ### 1-3. 한글 글꼴 설정(Windows)

# %%
# if not os.path.exists("malgun.ttf"): 
#     wget.download("https://www.wfonts.com/download/data/2016/06/13/malgun-gothic/malgun.ttf")
# if 'malgun' not in fm.fontManager.findfont("Malgun Gothic"):
#     fm.fontManager.addfont("malgun.ttf")
# if plt.rcParams['font.family']!= ["Malgun Gothic"]:
#     plt.rcParams['font.family']= [font for font in fm.fontManager.ttflist if 'malgun.ttf' in font.fname][-1].name
# plt.rcParams['axes.unicode_minus'] = False #한글 폰트 사용시 마이너스 폰트 깨짐 해결
# assert plt.rcParams['font.family'] == ["Malgun Gothic"], "한글 폰트가 설정되지 않았습니다."
# FONT_PATH = "malgun.ttf"

# %% [markdown]
# ### 1-4. 자바 경로 설정(Windows)

# %%
# os.environ['JAVA_HOME'] = "C:\Program Files\Java\jdk-19"

# %% [markdown]
# ### 1-3. 한글 글꼴 설정(Colab)

# %%
# !sudo apt-get install -y fonts-nanum
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# fonts-nanum is already the newest version (20180306-3).
# 0 upgraded, 0 newly installed, 0 to remove and 23 not upgraded.

# %%
# FONT_PATH = '/usr/share/fonts/truetype/nanum/NanumGothic.ttf'
# font_name = fm.FontProperties(fname=FONT_PATH, size=10).get_name()
# fm.fontManager.addfont(FONT_PATH)
# print(font_name)

# # plt.rcParams['font.family']=font_name
# plt.rcParams['axes.unicode_minus'] = False # 한글 폰트 사용시 마이너스 폰트 깨짐 해결
# assert plt.rcParams['font.family'] == [font_name], "한글 폰트가 설정되지 않았습니다."

# %% [markdown]
# ### 1-4. 구글드라이브 연결(Colab)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 2.데이터 불러오기

# %% [markdown]
# * 주어진 데이터
#  - 학습 및 검증용 데이터 : train.csv

# %% [markdown]
# ### 2-1. 데이터 로딩
#
# * 다음 데이터를 불러옵니다.
#     * 학습 및 검증용 데이터 : train.csv
#     * shape를 확인합니다.

# %%
data_path = '/content/drive/MyDrive/에이블스쿨/실습파일/2023.04.03_미니프로젝트4차_실습자료/train.csv'
data = pd.read_csv(data_path)

# %%
data.shape
# Out:
# (3706, 2)

# %% [markdown]
# ### 2-2. 데이터 확인하기
# * 문의 유형 분포 확인
# * data type, 결측치 확인

# %%
data.head()
# Out:
#                                                 text label
# 0  self.convs1 = nn.ModuleList([nn.Conv2d(1, Co, ...   코드2
# 1  현재 이미지를 여러개 업로드 하기 위해 자바스크립트로 동적으로 폼 여러개 생성하는데...     웹
# 2  glob.glob(PATH) 를 사용할 때 질문입니다.\n\nPATH에 [ ] 가 ...   코드2
# 3  tmpp = tmp.groupby(by = 'Addr1', as_index=Fals...   코드2
# 4  filename = TEST_IMAGE + str(round(frame_sec)) ...   코드2

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3706 entries, 0 to 3705
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    3706 non-null   object
#  1   label   3706 non-null   object
# dtypes: object(2)
# memory usage: 58.0+ KB

# %%
data.isna().sum()
# Out:
# text     0
# label    0
# dtype: int64

# %%
data.groupby(['label'], as_index=False)['text'].count()
# Out:
#     label  text
# 0  시스템 운영   561
# 1      원격   100
# 2       웹   732
# 3      이론   728
# 4     코드1   488
# 5     코드2  1097

# %%
sns.countplot(x = data['label'])
plt.show()

# %% [markdown]
# ## 3.데이터 탐색하기

# %% [markdown]
# ### 3-1. 문의 내용 길이 분포
#
# * 문의 내용의 길이 분포를 확인합니다.
# * 최소, 최대 길이의 index 및 문의 내용을 확인합니다.

# %%
data['text_len'] = data['text'].apply(lambda x: len(x)) # text 길이 컬럼 생성
data.head()
# Out:
#                                                 text label  text_len
# 0  self.convs1 = nn.ModuleList([nn.Conv2d(1, Co, ...   코드2       144
# 1  현재 이미지를 여러개 업로드 하기 위해 자바스크립트로 동적으로 폼 여러개 생성하는데...     웹       119
# 2  glob.glob(PATH) 를 사용할 때 질문입니다.\n\nPATH에 [ ] 가 ...   코드2       147
# 3  tmpp = tmp.groupby(by = 'Addr1', as_index=Fals...   코드2       279
# 4  filename = TEST_IMAGE + str(round(frame_sec)) ...   코드2       144

# %%
sns.histplot(data['text_len'], kde=True)
plt.show()

# %%
np.argmax(data['text_len']), np.argmin(data['text_len']) # text 길이가 가장 길고, 짧은 데이터 index
# Out:
# (2561, 756)

# %%
data.loc[np.argmax(data['text_len'])] # 가장 긴 데이터
# Out:
# text        sns.kdeplot(x = td[var])\nplt.show()\n\n------...
# label                                                     코드2
# text_len                                                 6012
# Name: 2561, dtype: object

# %%
print(data.loc[np.argmax(data['text_len']), 'text']) # 가장 긴 데이터 내용 확인
# Out:
# sns.kdeplot(x = td[var])
# plt.show()
#
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
#  in
# ----&gt; 1 sns.kdeplot(x = td[var])
#       2 plt.show()
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---&gt; 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\distributions.py in kdeplot(x, y, shade, vertical, kernel, bw, gridsize, cut, clip, legend, cumulative, shade_lowest, cbar, cbar_ax, cbar_kws, ax, weights, hue, palette, hue_order, hue_norm, multiple, common_norm, common_grid, levels, thresh, bw_method, bw_adjust, log_scale, color, fill, data, data2, warn_singular, **kwargs)
#    1768             plot_kws["color"] = color
#    1769
# -&gt; 1770         p.plot_univariate_density(
#    1771             multiple=multiple,
#    1772             common_norm=common_norm,
#
# ~\anaconda3\lib\site-packages\seaborn\distributions.py in plot_univariate_density(self, multiple, common_norm, common_grid, warn_singular, fill, legend, estimate_kws, **plot_kws)
#     926
#     927         # Do the computation
# --&gt; 928         densities = self._compute_univariate_density(
#     929             self.data_variable,
#     930             common_norm,
#
# ~\anaconda3\lib\site-packages\seaborn\distributions.py in _compute_univariate_density(self, data_variable, common_norm, common_grid, estimate_kws, log_scale, warn_singular)
#     301         densities = {}
#     302
# --&gt; 303         for sub_vars, sub_data in self.iter_data("hue", from_comp_data=True):
#     304
#     305             # Extract the data points from this sub set and remove nulls
#
# ~\anaconda3\lib\site-packages\seaborn\_core.py in iter_data(self, grouping_vars, reverse, from_comp_data)
#     981
#     982         if from_comp_data:
# --&gt; 983             data = self.comp_data
#     984         else:
#     985             data = self.plot_data
#
# ~\anaconda3\lib\site-packages\seaborn\_core.py in comp_data(self)
#    1055                     orig = self.plot_data[var].dropna()
#    1056                 comp_col = pd.Series(index=orig.index, dtype=float, name=var)
# -&gt; 1057                 comp_col.loc[orig.index] = pd.to_numeric(axis.convert_units(orig))
#    1058
#    1059                 if axis.get_scale() == "log":
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __setitem__(self, key, value)
#     690
#     691         iloc = self if self.name == "iloc" else self.obj.iloc
# --&gt; 692         iloc._setitem_with_indexer(indexer, value, self.name)
#     693
#     694     def _validate_key(self, key, axis: int):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _setitem_with_indexer(self, indexer, value, name)
#    1635             self._setitem_with_indexer_split_path(indexer, value, name)
#    1636         else:
# -&gt; 1637             self._setitem_single_block(indexer, value, name)
#    1638
#    1639     def _setitem_with_indexer_split_path(self, indexer, value, name: str):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _setitem_single_block(self, indexer, value, name)
#    1849             # setting for extensionarrays that store dicts. Need to decide
#    1850             # if it's worth supporting that.
# -&gt; 1851             value = self._align_series(indexer, Series(value))
#    1852
#    1853         elif isinstance(value, ABCDataFrame) and name != "iloc":
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _align_series(self, indexer, ser, multiindex_indexer)
#    1985             # series, so need to broadcast (see GH5206)
#    1986             if sum_aligners == self.ndim and all(is_sequence(_) for _ in indexer):
# -&gt; 1987                 ser = ser.reindex(obj.axes[0][indexer[0]], copy=True)._values
#    1988
#    1989                 # single indexer
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in reindex(self, index, **kwargs)
#    4343     )
#    4344     def reindex(self, index=None, **kwargs):
# -&gt; 4345         return super().reindex(index=index, **kwargs)
#    4346
#    4347     def drop(
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in reindex(self, *args, **kwargs)
#    4809
#    4810         # perform the reindex on the axes
# -&gt; 4811         return self._reindex_axes(
#    4812             axes, level, limit, tolerance, method, fill_value, copy
#    4813         ).__finalize__(self, method="reindex")
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)
#    4830
#    4831             axis = self._get_axis_number(a)
# -&gt; 4832             obj = obj._reindex_with_indexers(
#    4833                 {axis: [new_index, indexer]},
#    4834                 fill_value=fill_value,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _reindex_with_indexers(self, reindexers, fill_value, copy, allow_dups)
#    4875
#    4876             # TODO: speed up on homogeneous DataFrame objects
# -&gt; 4877             new_data = new_data.reindex_indexer(
#    4878                 index,
#    4879                 indexer,
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, consolidate, only_slice)
#    1299         # some axes don't allow reindexing with dups
#    1300         if not allow_dups:
# -&gt; 1301             self.axes[axis]._can_reindex(indexer)
#    1302
#    1303         if axis &gt;= self.ndim:
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in _can_reindex(self, indexer)
#    3474         # trying to reindex on an axis with duplicates
#    3475         if not self._index_as_unique and len(indexer):
# -&gt; 3476             raise ValueError("cannot reindex from a duplicate axis")
#    3477
#    3478     def reindex(self, target, method=None, level=None, limit=None, tolerance=None):
#
# ValueError: cannot reindex from a duplicate axis

# %%
data.loc[np.argmin(data['text_len'])] # 가장 짧은 데이터
# Out:
# text        원격 부탁드립니다
# label              원격
# text_len            9
# Name: 756, dtype: object

# %% [markdown]
# ### 3-2. 명사 추출하고 품사 태깅하기
#
# * konlpy, MeCab을 활용하여 품사 태깅, 명사 추출하기.
# * 2개 이상의 형태소 분석기를 Time analysis 해보기
# * Number of Samples / Number of words per sample 구해보기

# %%
# %%time
from konlpy.tag import Okt
okt = Okt()
morphs = []
morphs_count = []
nouns = []
for i in data['text']:
    temp = okt.morphs(i)
    temp2 = okt.nouns(i)
    morphs.append(' '.join(temp))
    morphs_count.append(len(temp))
    nouns.append(' '.join(temp2))
# Out:
# CPU times: user 1min 18s, sys: 325 ms, total: 1min 19s
# Wall time: 1min 19s

# %%
temp # okt.morphs(i) 결과
# Out:
# ['상관관계',
#  '는',
#  '그렇게',
#  '크지',
#  '않게',
#  '나오는데',
#  'p',
#  '-',
#  'value',
#  '값',
#  '은',
#  '관련',
#  '이',
#  '있게',
#  '나오는데',
#  '이',
#  '경우',
#  '에는',
#  '어떻게',
#  '해석',
#  '을',
#  '해야하나요',
#  '?']

# %%
temp2 # okt.nouns(i) 결과
# Out:
# ['상관관계', '값', '관련', '이', '경우', '해석']

# %%
print(f'Number of Samples : {len(morphs_count)}')
print(f'Number of morphs per sample : {sum(morphs_count) / len(morphs_count):.2f}')
# Out:
# Number of Samples : 3706
# Number of morphs per sample : 70.70

# %%
m = MeCab()
m.pos(data['text'][np.argmin(data['text_len'])]) # 가장 짧은 데이터에서 MeCab 결과 확인해보기
# Out:
# [('원격', 'NNG'), ('부탁', 'NNG'), ('드립니다', 'VV+EC')]

# %%
[x[0] for x in m.pos(data['text'][np.argmin(data['text_len'])])]
# Out:
# ['원격', '부탁', '드립니다']

# %%
# %%time
morphs = []
morphs_count = []
pos = []
nouns = []
for i in data['text']:
    p = m.pos(i)
    pos.extend(p)
    temp = [x[0] for x in p]
    temp2 = m.nouns(i)
    morphs.append(' '.join(temp))
    morphs_count.append(len(temp))
    nouns.append(' '.join(temp2))
# Out:
# CPU times: user 6.57 s, sys: 34.9 ms, total: 6.6 s
# Wall time: 6.65 s

# %%
pos[:5]
# Out:
# [('self', 'SL'), ('.', 'SY'), ('convs', 'SL'), ('1', 'SN'), ('=', 'SY')]

# %%
temp2
# Out:
# ['상관', '관계', '값', '관련', '경우', '해석']

# %%
print(f'Number of Samples : {len(morphs_count)}')
print(f'Number of morphs per sample : {sum(morphs_count) / len(morphs_count):.2f}')
# Out:
# Number of Samples : 3706
# Number of morphs per sample : 80.27

# %%
data['morphs'] = morphs
data['morphs_count'] = morphs_count
data['nouns'] = nouns
data.head()
# Out:
#                                                 text label  text_len  \
# 0  self.convs1 = nn.ModuleList([nn.Conv2d(1, Co, ...   코드2       144
# 1  현재 이미지를 여러개 업로드 하기 위해 자바스크립트로 동적으로 폼 여러개 생성하는데...     웹       119
# 2  glob.glob(PATH) 를 사용할 때 질문입니다.\n\nPATH에 [ ] 가 ...   코드2       147
# 3  tmpp = tmp.groupby(by = 'Addr1', as_index=Fals...   코드2       279
# 4  filename = TEST_IMAGE + str(round(frame_sec)) ...   코드2       144
#
#                                               morphs  morphs_count  \
# 0  self . convs 1 = nn . ModuleList ( [ nn . Conv...            66
# 1  현재 이미지 를 여러 개 업로드 하 기 위해 자바 스크립트 로 동적 으로 폼 여러 ...            55
# 2  glob . glob ( PATH ) 를 사용 할 때 질문 입니다 . PATH 에 ...            70
# 3  tmpp = tmp . groupby ( by = ' Addr 1 ', as _ i...           100
# 4  filename = TEST _ IMAGE + str ( round ( frame ...            55
#
#                                                nouns
# 0                       여기 커널 사이즈 은 단어 최대 길이 가정 선언 것
# 1  이미지 개 업로드 자바 스크립트 동적 폼 개 생성 데 클릭 뭘 수 기본 예제 코드 ...
# 2          사용 때 질문 포함 작동 것 질문 제공 파일 폴더 포함 폴더 안 정상 작동
# 3                                              오류 해결
# 4                안 폴더 안 이미지 저장 걸로 이해 실행 폴더 이미지 저장 질문

# %% [markdown]
# ### 3-3. nltk로 텍스트 분석하기
# * 3-2.의 명사 추출, 품사 태깅한 데이터를 nltk Text로 변경하기
# * 각각 token 갯수 / 전체 token 비율(Type-Token Ratio) 알아보기
# * 각각 Frequency 확인 및 분포 시각화
# * 명사 추출한 데이터에서 코드, 웹, 이론, 원격, 시스템 등 관심있는 각 단어에 분석해보기
# * 각각 collocation 확인
# * 최소 길이 문의 내용에 대해 grammar pasing 해보기(아래 코드 활용)
#
#
# ```python
# grammar = """
# NP: {<N.*>*<Suffix>?}   # Noun phrase
# VP: {<V.*>*}            # Verb phrase
# AP: {<A.*>*}            # Adjective phrase
# """
# NP_grammar = "NP: {<Adjective>*<Noun>*}"
# ```

# %%
from collections import Counter

cnt = Counter(pos)
print('nmorphs :', len(cnt))
print(f'nmorphs / nchars : {len(cnt) / len(pos) :.2f}')
# Out:
# nmorphs : 11980
# nmorphs / nchars : 0.04

# %%
# 형태소별 개수 상위 30개
temp = Counter([x[0] for x in pos]).most_common(30)
x, y = [], []
for i, j in temp:
    x.append(i)
    y.append(j)
plt.bar(x, y)
plt.xticks(rotation=90)
plt.show()

# %%
# 품사별 개수 상위 30개
temp = Counter([x[1] for x in pos]).most_common(30)
x, y = [], []
for i, j in temp:
    x.append(i)
    y.append(j)
plt.bar(x, y)
plt.xticks(rotation=90)
plt.show()

# %%
# 명사별 개수 상위 30개
temp = Counter(' '.join(nouns).split()).most_common(30)
x, y = [], []
for i, j in temp:
    x.append(i)
    y.append(j)
plt.bar(x, y)
plt.xticks(rotation=90)
plt.show()

# %%
import nltk
temp = ' '.join([x for x in data['morphs']]).split()
temp = nltk.Text(temp)
print(len(temp.tokens))
print(len(set(temp.tokens)))
temp.vocab()
# Out:
# 297493
# 11063
# FreqDist({'.': 10783, '(': 6452, ',': 6362, '-': 5845, ')': 5668, '_': 5425, '하': 5410, '는': 4475, '이': 4155, '=': 4081, ...})

# %%
temp.plot(30)
# Out:
# <Axes: xlabel='Samples', ylabel='Counts'>

# %%
for i in data['label'].unique():
    print(i, 'similar :')
    temp.similar(i)
    print('-' * 50)
# Out:
# 코드2 similar :
# No matches
# --------------------------------------------------
# 웹 similar :
# 면 어디 파이썬 기 안 코드 질문 어 해결 실행 고 문제 실습 라 경우 다음 조건 이후 변수 때문
# --------------------------------------------------
# 이론 similar :
# 현재 코드 질문 와 실습 번 전처리 과정 혹시 ㅠㅠ 이번 수업 클라우드 어제 modelcheckpoint xgb 문득
# --------------------------------------------------
# 코드1 similar :
# No matches
# --------------------------------------------------
# 시스템 운영 similar :
# No matches
# --------------------------------------------------
# 원격 similar :
# 피드백 axis 설명 방법 무엇 도움 자동 시간 과 값 변량 확인 그런데 과정 답 ㅠㅠ 그림 print 식 label
# --------------------------------------------------

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
temp.collocations()
# Out:
# 데이터 프레임; recent call; call last; File "",; "", line; import sys;
# python manage; 드려도 될까요; -*- coding; init __.; \__ init; 라우팅 테이블; 테스트
# 케이스; pip install; 데이터 전처리; 하이퍼 파라미터; -*- import; return self; ']].
# sum; module named

# %%
temp.collocation_list()
# Out:
# [('데이터', '프레임'),
#  ('recent', 'call'),
#  ('call', 'last'),
#  ('File', '"",'),
#  ('"",', 'line'),
#  ('import', 'sys'),
#  ('python', 'manage'),
#  ('드려도', '될까요'),
#  ('-*-', 'coding'),
#  ('init', '__.'),
#  ('\\__', 'init'),
#  ('라우팅', '테이블'),
#  ('테스트', '케이스'),
#  ('pip', 'install'),
#  ('데이터', '전처리'),
#  ('하이퍼', '파라미터'),
#  ('-*-', 'import'),
#  ('return', 'self'),
#  ("']].", 'sum'),
#  ('module', 'named')]

# %%
import konlpy

# %%
# !pip install svgling
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting svgling
#   Downloading svgling-0.3.1-py3-none-any.whl (21 kB)
# Collecting svgwrite
#   Downloading svgwrite-1.4.3-py3-none-any.whl (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.1/67.1 KB 6.1 MB/s eta 0:00:00
# Installing collected packages: svgwrite, svgling
# Successfully installed svgling-0.3.1 svgwrite-1.4.3

# %%
# 최소길이 문의에 대해 grammar parsing

grammar = """
NP: {<N.*>*<Suffix>?}   # Noun phrase
VP: {<V.*>*}            # Verb phrase
AP: {<A.*>*}            # Adjective phrase
"""
NP_grammar = "NP: {<Adjective>*<Noun>*}"

sentence = data.loc[np.argmin(data['text_len']), 'text'] # 가장 짧은 데이터
m = MeCab()
words = m.pos(sentence)

parser = nltk.RegexpParser(grammar)
chunks = parser.parse(words)
print(chunks.pprint())

for subtree in chunks.subtrees():
    if subtree.label() == 'NP':
        print(' '.join((e[0] for e in list(subtree))))
        print(subtree.pprint())

display(chunks)
# Out:
# (S (NP 원격/NNG 부탁/NNG) (VP 드립니다/VV+EC))
# None
# 원격 부탁
# (NP 원격/NNG 부탁/NNG)
# None
# Tree('S', [Tree('NP', [('원격', 'NNG'), ('부탁', 'NNG')]), Tree('VP', [('드립니다', 'VV+EC')])])

# %% [markdown]
# ### 3-4. Wordcloud 만들기
# * 명사 추출/형태소 분석 결과를 이용하여 WordCloud 객체를 생성
# * 최대 글꼴 크기(max_font_size), 최대 단어 수(max_words), 배경 색상(background_color)
# * 상대 크기비율(relative_scaling), 그림 크기(width, height), 폰트 경로(font_path=FONT_PATH) 등 설정
# * .generate 메서드를 연결하여 WordCloud에 사용될 텍스트 데이터 생성
# * plt.imshow(  ) 를 통해 화면에 보여집니다.

# %%
from wordcloud import WordCloud
temp = ' '.join(nouns)
wordcloud = WordCloud(font_path='NanumBarunGothic', max_font_size=100).generate(temp)
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %%
temp = ' '.join(data['morphs'])
wordcloud = WordCloud(font_path='NanumBarunGothic', max_font_size=100).generate(temp)
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %% [markdown]
# ## 4. 문의 유형에 따른 분석
# ### 4-1. *3. 데이터 탐색*에서 실행한 알고리즘을 문의 유형에 따라 실행할 수 있는 함수를 개발합니다.
# * 아래 text_analysis 함수를 개발합니다.

# %%
def text_analysis(df, label=None):
    """
    label에 따라서 분석, label이 None인 경우 전체 분석
    데이터 확인, 데이터 길이 시각화
    명사 추출하여 분석, 워드 클라우드 시각화

    Parameters
    ----------
    df : pandas DataFrame object.
    label : Label for analysis, default=None.
    - If label is None, Entire data are analyzed.

    Returns
    -------
    result : None

    """
    if label:
        df = df.loc[df['label'] == label]
    
    print('결측치 확인')
    print(df.isna().sum())
    print()
    plt.figure()
    plt.title('label 별 데이터 개수')
    sns.countplot(x = df['label'])
    plt.show()

    df['text_len'] = df['text'].apply(lambda x: len(x)) # text 길이 컬럼 생성
    plt.figure(figsize=(10, 10))
    plt.subplot(2, 1, 1)
    plt.title('text 길이')
    sns.histplot(df['text_len'], kde=True)

    m = MeCab()
    nouns = []
    for i in df['text']:
        temp = m.nouns(i)
        nouns.append(' '.join(temp))
    
    # 명사별 개수 상위 30개
    temp = Counter(' '.join(nouns).split()).most_common(30)
    x, y = [], []
    for i, j in temp:
        x.append(i)
        y.append(j)
    plt.subplot(2, 1, 2)
    plt.title('명사 별 개수 상위 30개')
    plt.bar(x, y)
    plt.xticks(rotation=90)
    plt.show()

    temp = ' '.join(nouns)
    wordcloud = WordCloud(font_path='NanumBarunGothic', max_font_size=100).generate(temp)
    plt.figure()
    plt.title('Word Cloud')
    plt.imshow(wordcloud)
    plt.axis('off')
    plt.show()

# %% [markdown]
# ### 4-2. 각각의 문의 유형에 대해 실행합니다.

# %%
for label in sorted(data.label.unique()):
    text_analysis(data,label)
# Out:
# 결측치 확인
# text            0
# label           0
# text_len        0
# morphs          0
# morphs_count    0
# nouns           0
# dtype: int64
# <ipython-input-232-76a346491ce5>:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['text_len'] = df['text'].apply(lambda x: len(x)) # text 길이 컬럼 생성
# 결측치 확인
# text            0
# label           0
# text_len        0
# morphs          0
# morphs_count    0
# nouns           0
# dtype: int64
# <ipython-input-232-76a346491ce5>:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['text_len'] = df['text'].apply(lambda x: len(x)) # text 길이 컬럼 생성
# 결측치 확인
# text            0
# label           0
# text_len        0
# morphs          0
# morphs_count    0
# nouns           0
# dtype: int64
# <ipython-input-232-76a346491ce5>:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['text_len'] = df['text'].apply(lambda x: len(x)) # text 길이 컬럼 생성
# 결측치 확인
# text            0
# label           0
# text_len        0
# morphs          0
# morphs_count    0
# nouns           0
# dtype: int64
# <ipython-input-232-76a346491ce5>:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['text_len'] = df['text'].apply(lambda x: len(x)) # text 길이 컬럼 생성
# 결측치 확인
# text            0
# label           0
# text_len        0
# morphs          0
# morphs_count    0
# nouns           0
# dtype: int64
# <ipython-input-232-76a346491ce5>:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['text_len'] = df['text'].apply(lambda x: len(x)) # text 길이 컬럼 생성
# 결측치 확인
# text            0
# label           0
# text_len        0
# morphs          0
# morphs_count    0
# nouns           0
# dtype: int64
# <ipython-input-232-76a346491ce5>:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['text_len'] = df['text'].apply(lambda x: len(x)) # text 길이 컬럼 생성

# %%
text_analysis(data)
# Out:
# 결측치 확인
# text            0
# label           0
# text_len        0
# morphs          0
# morphs_count    0
# nouns           0
# dtype: int64

# %% [markdown]
# # 단계2 : 데이터 전처리
# > * Tokenization(Konlpy...)
# > * Vectorization(N-grams, Sequence)
# > * [Google guide](https://developers.google.com/machine-learning/guides/text-classification/step-3)

# %% [markdown]
# ## 5. 데이터 준비
# ### 5-1. label 아래 형식으로 처리
# ```python
# label_dict = {
#     '코드1': 0,
#     '코드2': 0,
#     '웹': 1,
#     '이론': 2,
#     '시스템 운영': 3,
#     '원격': 4
# }
# ```

# %%
label_dict = {
    '코드1': 0,
    '코드2': 0,
    '웹': 1,
    '이론': 2,
    '시스템 운영': 3,
    '원격': 4
}

df = data.replace(label_dict)
df.head()
# Out:
#                                                 text  label  text_len  \
# 0  self.convs1 = nn.ModuleList([nn.Conv2d(1, Co, ...      0       144
# 1  현재 이미지를 여러개 업로드 하기 위해 자바스크립트로 동적으로 폼 여러개 생성하는데...      1       119
# 2  glob.glob(PATH) 를 사용할 때 질문입니다.\n\nPATH에 [ ] 가 ...      0       147
# 3  tmpp = tmp.groupby(by = 'Addr1', as_index=Fals...      0       279
# 4  filename = TEST_IMAGE + str(round(frame_sec)) ...      0       144
#
#                                               morphs  morphs_count  \
# 0  self . convs 1 = nn . ModuleList ( [ nn . Conv...            66
# 1  현재 이미지 를 여러 개 업로드 하 기 위해 자바 스크립트 로 동적 으로 폼 여러 ...            55
# 2  glob . glob ( PATH ) 를 사용 할 때 질문 입니다 . PATH 에 ...            70
# 3  tmpp = tmp . groupby ( by = ' Addr 1 ', as _ i...           100
# 4  filename = TEST _ IMAGE + str ( round ( frame ...            55
#
#                                                nouns
# 0                       여기 커널 사이즈 은 단어 최대 길이 가정 선언 것
# 1  이미지 개 업로드 자바 스크립트 동적 폼 개 생성 데 클릭 뭘 수 기본 예제 코드 ...
# 2          사용 때 질문 포함 작동 것 질문 제공 파일 폴더 포함 폴더 안 정상 작동
# 3                                              오류 해결
# 4                안 폴더 안 이미지 저장 걸로 이해 실행 폴더 이미지 저장 질문

# %% [markdown]
# ### 5-2. Train Validation split

# %%
from sklearn.model_selection import train_test_split
x = df['morphs']
y = df['label']

x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=0.2, random_state=2023, stratify=y)
x_train.shape, x_val.shape, y_train.shape, y_val.shape
# Out:
# ((2964,), (742,), (2964,), (742,))

# %% [markdown]
# ## 6. 데이터 처리

# %% [markdown]
# ### 6-1. 특수문자 제거(Optional)
# - [정규표현식 이용](https://docs.python.org/3/howto/regex.html)

# %%
import re

str = "AA**BB#@$CC 가나다-123"

new_str = re.sub(r"[^\uAC00-\uD7A30-9a-zA-Z\s]", "", str)
print(new_str)
# Out:
# AABBCC 가나다123

# %%
x
# Out:
# 0       self . convs 1 = nn . ModuleList ( [ nn . Conv...
# 1       현재 이미지 를 여러 개 업로드 하 기 위해 자바 스크립트 로 동적 으로 폼 여러 ...
# 2       glob . glob ( PATH ) 를 사용 할 때 질문 입니다 . PATH 에 ...
# 3       tmpp = tmp . groupby ( by = ' Addr 1 ', as _ i...
# 4       filename = TEST _ IMAGE + str ( round ( frame ...
#                               ...
# 3701    토큰 화 이후 train val 를 분리 하 고 각 train set , val s...
# 3702    올린 값 들 중 최고점 인 건가요 ? 아니면 최근 에 올린 파일 로 무조건 갱신 인...
# 3703    수업 에서 cacoo 랑 packet tracer 를 배우 는 이유 가 1 . IT...
# 3704    inplace = True 해도 값 이 변경 이 안 되 고 none 으로 뜹니다 ....
# 3705    상관 관계 는 그렇게 크 지 않 게 나오 는데 p - value 값 은 관련 이 있...
# Name: morphs, Length: 3706, dtype: object

# %%
x.apply(lambda x: re.sub(r"[^\uAC00-\uD7A30-9a-zA-Z\s]", "", x))
# Out:
# 0       self  convs 1  nn  ModuleList   nn  Conv 2 d  ...
# 1       현재 이미지 를 여러 개 업로드 하 기 위해 자바 스크립트 로 동적 으로 폼 여러 ...
# 2       glob  glob  PATH  를 사용 할 때 질문 입니다  PATH 에   가 ...
# 3       tmpp  tmp  groupby  by   Addr 1  as  index  Fa...
# 4       filename  TEST  IMAGE  str  round  frame  sec ...
#                               ...
# 3701    토큰 화 이후 train val 를 분리 하 고 각 train set  val se...
# 3702    올린 값 들 중 최고점 인 건가요  아니면 최근 에 올린 파일 로 무조건 갱신 인가...
# 3703    수업 에서 cacoo 랑 packet tracer 를 배우 는 이유 가 1  IT ...
# 3704    inplace  True 해도 값 이 변경 이 안 되 고 none 으로 뜹니다  혹...
# 3705    상관 관계 는 그렇게 크 지 않 게 나오 는데 p  value 값 은 관련 이 있 ...
# Name: morphs, Length: 3706, dtype: object

# %%
x_train = x_train.apply(lambda x: re.sub(r"[^\uAC00-\uD7A30-9a-zA-Z\s]", "", x))
x_val = x_val.apply(lambda x: re.sub(r"[^\uAC00-\uD7A30-9a-zA-Z\s]", "", x))

# %% [markdown]
# ### 6-2. N-grams (sklearn)
# > * [scikit-learn working with text data](https://scikit-learn.org/stable/tutorial/text_analytics/working_with_text_data.html#)
# > * [scikit-learn text feature extraction](https://scikit-learn.org/stable/modules/feature_extraction.html#text-feature-extraction)
# > * [한글 자료](https://datascienceschool.net/03%20machine%20learning/03.01.03%20Scikit-Learn%EC%9D%98%20%EB%AC%B8%EC%84%9C%20%EC%A0%84%EC%B2%98%EB%A6%AC%20%EA%B8%B0%EB%8A%A5.html)

# %%
x_train
# Out:
# 3002    안녕 하 세요 질문 드립니다  stu 01    no  1   name   홍길동 ...
# 2724     5  검증  예측 pl  ml  predict  x  val  pl pl  rea...
# 80      지금 현재 문자열 에서 float 으로 변환 하 는 것 은 불 가능 으로 보입니다 ...
# 2607    kubeadm join 제 꺼 복 붙 하고 입력 했 는데 저렇게 중간 에 잘리 고 ...
# 1723    수치 화 과정 에서 Age 열 에 결 측 치가 있 어 결 측 치 를 제거 했 더니 ...
#                               ...
# 2553    test dataset 을 detect 를 할 때  모델 이 예측 한 각 objec...
# 2694    RTB 에 대해 생각 하 다가 의문 이 하나 들 었 습니다  1  보통 키오스 크 ...
# 2415    항상 자세 한 설명 감사 드립니다  금방 강의 중 with open  f  path...
# 3254    Yes  data  loc  data   US  Yes   Sales  No  da...
# 182     elements  dom  select   gBestWrap  gt  div  gt...
# Name: morphs, Length: 2964, dtype: object

# %%
from sklearn.feature_extraction.text import CountVectorizer

vect = CountVectorizer()
vect.fit(x_train)
vect.vocabulary_

# %%
vect = CountVectorizer(ngram_range=(2, 2)).fit(x_train)
vect.vocabulary_
# Out:
# {'안녕 세요': 39539,
#  '세요 질문': 36571,
#  '질문 드립니다': 49604,
#  '드립니다 stu': 28771,
#  'stu 01': 16807,
#  '01 no': 81,
#  'no name': 12507,
#  'name 홍길동': 12332,
#  '홍길동 score': 55406,
#  'score 92': 15489,
#  '92 96': 2868,
#  '96 98': 2924,
#  '98 mean': 2939,
#  'mean 95': 11634,
#  '95 3333333': 2900,
#  '3333333 print': 1815,
#  'print 학생': 14257,
#  '학생 평균': 53461,
#  '평균 점수': 52745,
#  '점수 stu': 47420,
#  '01 mean': 80,
#  'mean 입니다': 11661,
#  '입니다 같이': 46137,
#  '같이 딕셔너리': 20264,
#  '딕셔너리 만들': 29152,
#  '만들 mean': 30636,
#  'mean 대하': 11653,
#  '대하 소수점': 27453,
#  '소수점 둘째': 36706,
#  '둘째 자리': 28624,
#  '자리 까지': 46539,
#  '까지 출력': 23880,
#  '출력 려고': 50741,
#  '려고 는데': 30089,
#  '는데 print': 25446,
#  'print 같이': 14182,
#  '같이 string': 20231,
#  'string 이용': 16790,
#  '이용 해서': 45176,
#  '해서 출력': 54667,
#  '출력 걸까요': 50702,
#  '걸까요 신택스': 20813,
#  '신택스 에러': 38370,
#  '에러 뜹니다': 40584,
#  '뜹니다 감사': 29561,
#  '감사 합니다': 19972,
#  '검증 예측': 20959,
#  '예측 pl': 42162,
#  'pl ml': 13677,
#  'ml predict': 11887,
#  'predict val': 13993,
#  'val pl': 18467,
#  'pl pl': 13678,
#  'pl real': 13679,
#  'real pl': 14714,
#  'pl train': 13681,
#  'train max': 17834,
#  'max train': 11570,
#  'train min': 17835,
#  'min train': 11828,
#  'min pl': 11822,
#  'real 예측': 14717,
#  '예측 단계': 42181,
#  '단계 에서': 27005,
#  '에서 pl': 40827,
#  'real 실제': 14716,
#  '실제 라고': 38569,
#  '라고 이해': 29716,
#  '이해 갑니다': 45337,
#  '갑니다 곡선': 19983,
#  '곡선 자체': 21878,
#  '자체 강사': 46596,
#  '강사 이랑': 20076,
#  '이랑 다르': 44643,
#  '다르 나온': 26426,
#  '나온 은데': 24263,
#  '은데 뭔가': 44068,
#  '뭔가 잘못': 32184,
#  '잘못 걸까요': 46814,
#  '지금 현재': 48983,
#  '현재 문자열': 55019,
#  '문자열 에서': 31901,
#  '에서 float': 40738,
#  'float 으로': 7743,
#  '으로 변환': 43637,
#  '변환 가능': 33435,
#  '가능 으로': 19523,
#  '으로 보입니다': 43641,
#  '보입니다 생활': 33662,
#  '생활 인구수': 35691,
#  '인구수 예측': 45603,
#  '예측 위한': 42209,
#  '위한 컬럼': 43125,
#  '컬럼 예측': 51064,
#  '예측 위해서': 42210,
#  '위해서 만든': 43209,
#  '만든 shift': 30604,
#  'shift 이용한': 16075,
#  '이용한 컬럼': 45179,
#  '컬럼 제외': 51069,
#  '제외 날짜': 48161,
#  '날짜 시간': 24684,
#  '시간 컬럼': 38054,
#  '컬럼 지워도': 51070,
#  '지워도 으로': 49206,
#  '보입니다 shift': 33655,
#  'shift 현재': 16083,
#  '현재 int': 54988,
#  'int 64': 9913,
#  '64 ns': 2491,
#  'ns 형식': 12726,
#  '형식 인데': 55097,
#  '인데 지우': 45682,
#  '지우 기준일': 49185,
#  '기준일 id': 23682,
#  'id 지우': 8965,
#  '지우 라는': 49189,
#  '라는 말씀': 29776,
#  'kubeadm join': 10545,
#  'join 하고': 10298,
#  '하고 입력': 53277,
#  '입력 는데': 46283,
#  '는데 저렇게': 25861,
#  '저렇게 중간': 46956,
#  '중간 잘리': 48821,
#  '잘리 bash': 46806,
#  'bash kubeadm': 4066,
#  'kubeadm no': 10546,
#  'no such': 12518,
#  'such file': 16864,
#  'file or': 7545,
#  'or directory': 13117,
#  'directory 저런': 6315,
#  '저런 상태': 46945,
#  '상태 는데': 35355,
#  '는데 어떻게': 25767,
#  '어떻게 나요': 39972,
#  '수치 과정': 36994,
#  '과정 에서': 22008,
#  '에서 age': 40654,
#  'age 치가': 3178,
#  '치가 제거': 50890,
#  '제거 더니': 47975,
#  '더니 첨부': 27679,
#  '첨부 파일': 50300,
#  '파일 수치': 52361,
#  '수치 강사': 36991,
#  '강사 결과': 20032,
#  '결과 첨부': 21132,
#  '수치 다르': 36997,
#  '다르 나왔': 26430,
#  '나왔 습니다': 24421,
#  '습니다 제거': 37798,
#  '제거 실행': 47995,
#  '실행 nan': 38635,
#  'nan 으로': 12373,
#  '으로 결과': 43457,
#  '결과 나옵니다': 21058,
#  '나옵니다 어떻게': 24332,
#  '어떻게 해결': 40058,
#  '해결 해야': 54284,
#  '해야 는지': 54744,
#  '는지 도움': 26077,
#  '도움 부탁': 28113,
#  '부탁 드립니다': 34071,
#  '세요 항상': 36596,
#  '항상 자세': 54219,
#  '자세 답변': 46568,
#  '답변 셔서': 27168,
#  '셔서 감사': 36645,
#  '감사 드립니다': 19967,
#  '드립니다 오늘': 28880,
#  '오늘 교재': 42249,
#  '교재 다운로드': 22357,
#  '다운로드 pdf': 26892,
#  'pdf 네요': 13570,
#  '네요 다운로드': 25006,
#  '다운로드 버튼': 26903,
#  '버튼 눌러': 32997,
#  '눌러 반응': 25222,
#  '반응 는데': 32523,
#  '는데 첨부': 25905,
#  '파일 첨부': 52449,
#  '첨부 으실까': 50293,
#  'train 데이터': 17873,
#  '데이터 존재': 27993,
#  '존재 범주': 48529,
#  '범주 데이터': 33122,
#  '데이터 이외': 27967,
#  '이외 데이터': 45122,
#  '데이터 test': 27788,
#  'test 데이터': 17269,
#  '존재 변수': 48530,
#  '변수 과정': 33269,
#  '에서 train': 40895,
#  'train test': 17854,
#  'test 개수': 17260,
#  '개수 달라지': 20413,
#  '달라지 문제': 27118,
#  '문제 생길': 32046,
#  '생길 train': 35587,
#  '데이터 범주': 27893,
#  '데이터 범위': 27892,
#  '범위 value': 33082,
#  'value counts': 18559,
#  'counts 상위': 5357,
#  '상위 10': 35331,
#  '10 제한': 407,
#  '제한 나머지': 48320,
#  '나머지 데이터': 24127,
#  '데이터 모두': 27879,
#  '모두 others': 31431,
#  'others 수정': 13216,
#  '수정 오류': 36953,
#  '오류 해결': 42424,
#  '해결 고자': 54226,
#  '고자 습니다': 21839,
#  '습니다 test': 37500,
#  '데이터 train': 27791,
#  '데이터 포함': 28017,
#  '포함 데이터': 52808,
#  '데이터 others': 27780,
#  '수정 는데': 36921,
#  '는데 이것': 25822,
#  '이것 data': 44464,
#  'data leakage': 5643,
#  'leakage 해당': 10741,
#  '해당 건지': 54304,
#  '건지 궁금': 20744,
#  '궁금 합니다': 22735,
#  '원격 지원': 42975,
#  '지원 잘못': 49227,
#  '잘못 번호': 46832,
#  '번호 라고': 33047,
#  '라고 접속': 29721,
#  '접속 됩니다': 47500,
#  '세요 다음': 36472,
#  '다음 같이': 26928,
#  '같이 비디오': 20279,
#  '비디오 데이터': 34604,
#  '데이터 경로': 27809,
#  '경로 video': 21213,
#  'video list': 18788,
#  'list 저장': 11115,
#  '저장 상태': 47020,
#  '상태 입니다': 35380,
#  '입니다 튜토리얼': 46215,
#  '튜토리얼 에서': 52004,
#  '에서 opencv': 40819,
#  'opencv 통해': 13077,
#  '통해 video': 51900,
#  'video cv': 18780,
#  'cv videocapture': 5564,
#  'videocapture tutorial': 18804,
#  'tutorial path': 18087,
#  'path tutorial': 13494,
#  'tutorial mp': 18086,
#  'mp tutorial': 12130,
#  'tutorial 비디오': 18092,
#  '비디오 불러올': 34606,
#  '불러올 지만': 34476,
#  '지만 glob': 49024,
#  'glob 활용': 8188,
#  '활용 비디오': 55693,
#  '비디오 불러오': 34605,
#  '불러오 방법': 34441,
#  '방법 에서': 32742,
#  '에서 막힌': 41058,
#  '막힌 상황': 30576,
#  '상황 입니다': 35411,
#  '입니다 구글링': 46140,
#  '구글링 개념': 22414,
#  '개념 지만': 20356,
#  '지만 경로': 49048,
#  '경로 불러오': 21221,
#  '방법 나와': 32700,
#  '나와 어도': 24363,
#  '어도 glob': 39737,
#  'glob 라이브러리': 8187,
#  '라이브러리 활용': 29966,
#  '활용 파일': 55701,
#  '파일 불러': 52347,
#  '불러 와서': 34417,
#  '와서 특정': 42655,
#  '특정 이름': 52063,
#  '이름 으로': 44893,
#  '으로 저장': 43768,
#  '저장 방법': 47016,
#  '방법 못했': 32722,
#  '못했 습니다': 31721,
#  '습니다 park': 37472,
#  'park cv': 13385,
#  'videocapture video': 18805,
#  'list park': 11071,
#  'park mp': 13386,
#  'mp 라는': 12134,
#  '라는 코드': 29825,
#  '코드 작성': 51334,
#  '작성 해도': 46751,
#  '해도 can': 54391,
#  'can only': 4520,
#  'only concatenate': 13025,
#  'concatenate list': 5104,
#  'list not': 11066,
#  'not str': 12651,
#  'str to': 16744,
#  'to list': 17661,
#  'list 라는': 11099,
#  '라는 오류': 29804,
#  '오류 뜹니다': 42358,
#  '뜹니다 혹시': 29611,
#  '혹시 조언': 55320,
#  '조언 을까요': 48425,
#  '현재 수치': 55029,
#  '수치 범위': 37001,
#  '범위 범주': 33095,
#  '범주 나누': 33120,
#  '나누 습니다': 24065,
#  '습니다 경우': 37536,
#  '경우 분산분석': 21394,
#  '분산분석 기에': 34244,
#  '기에 다시': 23593,
#  '다시 수치': 26786,
#  '수치 나누': 36996,
#  '나누 은데': 24071,
#  '은데 방법': 44071,
#  '방법 모르': 32719,
#  '모르 습니다': 31558,
#  '아까 질문': 38893,
#  '질문 어서': 49633,
#  '어서 합니다': 40253,
#  '합니다 모델': 54035,
#  '모델 통해서': 31365,
#  '통해서 다시': 51955,
#  '다시 설정': 26782,
#  '설정 보다': 36133,
#  '보다 gridsearch': 33526,
#  'gridsearch 이용': 8294,
#  '해서 파라미터': 54672,
#  '파라미터 어떻게': 52165,
#  '어떻게 설정': 40004,
#  '설정 였을': 36150,
#  '였을 score': 41946,
#  'score 만들': 15522,
#  '만들 는지': 30657,
#  '는지 확인': 26163,
#  '확인 한다고': 55623,
#  '한다고 생각': 53599,
#  '생각 습니다': 35509,
#  '습니다 라고': 37608,
#  '라고 답변': 29657,
#  '답변 는데': 27158,
#  '는데 그렇': 25571,
#  '그렇 다면': 23188,
#  '다면 score': 26597,
#  'score 높히': 15516,
#  '높히 위해선': 25153,
#  '위해선 max': 43222,
#  'max depth': 11538,
#  'depth 다시': 6085,
#  '설정 해서': 36173,
#  '해서 model': 54502,
#  'model 선언': 11987,
#  '선언 해야': 35927,
#  '해야 건가요': 54730,
#  'replace 함수': 14855,
#  '함수 활용': 53901,
#  '활용 benign': 55678,
#  'benign malicious': 4148,
#  'malicious 변경': 11427,
#  '변경 세요': 33196,
#  '세요 삭제': 36504,
#  '삭제 df': 35180,
#  'df result': 6175,
#  'result 전후': 15088,
#  '전후 데이터': 47393,
#  '데이터 비교': 27911,
#  '비교 세요': 34582,
#  '세요 서울': 36509,
#  '서울 버스': 35847,
#  '버스 데이터': 32973,
#  '데이터 다운로드': 27842,
#  '다운로드 압축': 26910,
#  '압축 는데': 39631,
#  '는데 vol': 25499,
#  'vol egg': 18884,
#  'egg 압축': 6704,
#  '압축 풀리': 39639,
#  '풀리 풀리': 52956,
#  '풀리 는데': 52953,
#  '는데 혹시': 25954,
#  '혹시 해결': 55345,
#  '해결 방법': 54251,
#  '방법 나요': 32701,
#  '나요 vol': 24465,
#  'vol 려고': 18885,
#  '려고 시도': 30098,
#  '시도 는데': 38083,
#  '는데 계속': 25541,
#  '계속 부터': 21611,
#  '부터 파일': 34145,
#  '파일 라는': 52314,
#  '라는 문구': 29780,
#  '문구 상황': 31818,
#  '모델 머신': 31291,
#  '머신 러닝': 30978,
#  '러닝 최적화': 30027,
#  '최적화 에서': 50484,
#  '에서 module': 40801,
#  'module sixthmodule': 12055,
#  'sixthmodule id': 16184,
#  'id 단서': 8950,
#  '단서 돌리': 27025,
#  '돌리 valueerror': 28222,
#  'valueerror feature': 18627,
#  'feature names': 7411,
#  'names mismatch': 12342,
#  'mismatch distance': 11870,
#  'distance eta': 6340,
#  'eta signaltype': 7070,
#  'signaltype dummy': 16150,
#  'dummy dummy': 6579,
#  'dummy 인천광역시': 6585,
#  '인천광역시 에러': 45848,
#  '에러 납니다': 40570,
#  '납니다 해결': 24738,
#  '방법 도저히': 32711,
#  '도저히 어서': 28136,
#  '어서 질문': 40235,
#  '드립니다 심화': 28862,
#  '심화 문제': 38794,
#  '문제 에서': 32068,
#  'module seventhmodule': 12054,
#  'seventhmodule id': 15946,
#  'id 돌리': 8952,
#  'valueerror no': 18638,
#  'no model': 12505,
#  'model found': 11932,
#  'found in': 7893,
#  'in config': 9390,
#  'config file': 5121,
#  'file 에러': 7566,
#  'pretrainded model': 14022,
#  'model 가중치': 11978,
#  '가중치 사용': 19753,
#  '사용 한다는': 34996,
#  '한다는 가중치': 53611,
#  '가중치 정확히': 19763,
#  '정확히 어떤': 47943,
#  '어떤 인가요': 39889,
#  '인가요 backbone': 45485,
#  'backbone 구조': 4012,
#  '구조 전체': 22585,
#  '전체 의미': 47357,
#  '의미 나요': 44360,
#  '나요 아니면': 24542,
#  '아니면 구조': 39034,
#  '구조 에서': 22580,
#  '에서 계산': 40957,
#  '계산 사용': 21544,
#  '한다는 건가요': 53612,
#  'data response': 5667,
#  'response json': 14978,
#  'json items': 10325,
#  'items 코드': 10228,
#  '코드 에서': 51309,
#  '에서 부분': 41114,
#  '부분 따라서': 33942,
#  '따라서 어떤': 29208,
#  '어떤 차이': 39905,
#  '차이 건가요': 49776,
#  '건가요 일단': 20686,
#  '일단 출력': 45979,
#  '출력 표시': 50801,
#  '표시 정보': 52899,
#  '정보 차이': 47756,
#  '차이 은데': 49827,
#  '은데 차이': 44107,
#  '차이 궁금': 49781,
#  'plt rcparams': 13721,
#  'rcparams figure': 14653,
#  'figure figsize': 7520,
#  'figsize 10': 7510,
#  '10 숫자': 386,
#  '숫자 대괄호': 37141,
#  '대괄호 아닌': 27255,
#  '아닌 소괄호': 39124,
#  '소괄호 해서': 36678,
#  '해서 컴파일': 54669,
#  '컴파일 했는데도': 51075,
#  '했는데도 계속': 54853,
#  '계속 오류': 21629,
#  '파일 다운로드': 52295,
#  '다운로드 실행': 26908,
#  '실행 실습': 38716,
#  '실습 사진': 38477,
#  '사진 에러': 35112,
#  '에러 생겼': 40597,
#  '생겼 습니다': 35567,
#  '설명 으로': 36054,
#  '으로 머신': 43590,
#  '러닝 에서': 30018,
#  '에서 사용': 41129,
#  '사용 데이터': 34892,
#  '데이터 전처리': 27983,
#  '전처리 방식': 47305,
#  '방식 는데': 32781,
#  '는데 머신': 25643,
#  '러닝 교안': 29997,
#  '교안 에선': 22324,
#  '에선 못하': 41432,
#  '못하 어떤': 31676,
#  '어떤 파트': 39915,
#  '파트 에서': 52475,
#  '에서 labelencoder': 40782,
#  'labelencoder 관련': 10635,
#  '관련 내용': 22136,
#  '내용 나왔': 24787,
#  '나왔 는지': 24415,
#  '는지 알려': 26109,
#  '알려 감사': 39582,
#  '합니다 항상': 54153,
#  '항상 감사': 54204,
#  '세요 오늘': 36535,
#  '오늘 개인': 42245,
#  '개인 실습': 20465,
#  '실습 여소': 38503,
#  '여소 이용': 41663,
#  '이용 건수': 45130,
#  '건수 top': 20734,
#  'top 10': 17721,
#  '10 마지막': 375,
#  '마지막 10': 30485,
#  '10 데이터': 371,
#  '데이터 추출': 28003,
#  '추출 질문': 50647,
#  '드립니다 다른': 28809,
#  '다른 원분': 26528,
#  '원분 비교': 43011,
#  '비교 코드': 34598,
#  '코드 문제': 51272,
#  '문제 습니다': 32051,
#  '습니다 그리고': 37564,
#  '그리고 요구': 23331,
#  '요구 사항': 42731,
#  '사항 대로': 35152,
#  '대로 전처리': 27319,
#  '전처리 끝난': 47294,
#  '끝난 데이터': 24004,
#  '데이터 당산': 27844,
#  '당산 갑문': 27227,
#  '갑문 확인': 19987,
#  '확인 됩니다': 55546,
#  '됩니다 코드': 28609,
#  '코드 엑셀': 51310,
#  '엑셀 확인': 41450,
#  '확인 내용': 55534,
#  '내용 첨부': 24877,
#  '첨부 드립니다': 50282,
#  '드립니다 감사': 28783,
#  '합니다 여소': 54081,
#  '10 tmp': 350,
#  'tmp bike': 17593,
#  'bike groupby': 4196,
#  'groupby by': 8307,
#  'by 여소': 4452,
#  '여소 as': 41656,
#  'as index': 3777,
#  'index false': 9600,
#  'false 이용': 7354,
#  '건수 sum': 20732,
#  'sum tmp': 16904,
#  'bike sort': 4203,
#  'sort values': 16329,
#  'values by': 18656,
#  'by 이용': 4456,
#  '건수 ascending': 20730,
#  'ascending false': 3803,
#  'false head': 7313,
#  'head 10': 8604,
#  'tmp 여소': 17614,
#  '10 시각': 387,
#  '시각 plt': 37908,
#  'plt figure': 13711,
#  'figsize 15': 7513,
#  '15 plt': 924,
#  'plt bar': 13709,
#  'bar tmp': 4039,
#  '여소 tmp': 41660,
#  'tmp 이용': 17616,
#  '건수 plt': 20731,
#  'plt title': 13729,
#  'title 여소': 17582,
#  '10 fontsize': 320,
#  'fontsize 15': 7765,
#  '15 pad': 923,
#  'pad 15': 13310,
#  'plt ticklabel': 13727,
#  'ticklabel format': 17508,
#  'format axis': 7867,
#  'axis style': 3983,
#  'style plain': 16820,
#  'plain plt': 13685,
#  'plt xticks': 13732,
#  'xticks rotation': 19302,
#  'rotation 70': 15254,
#  '70 plt': 2567,
#  'plt show': 13723,
#  '또는 경우': 29444,
#  '경우 plot': 21285,
#  'plot tree': 13700,
#  'tree 서드': 17958,
#  '서드 class': 35699,
#  'class names': 4738,
#  'names 파라미터': 12350,
#  '파라미터 각각': 52143,
#  '각각 대응': 19881,
#  '대응 순서': 27420,
#  '순서 인가요': 37101,
#  '인가요 아니면': 45545,
#  '아니면 반대': 39054,
#  '반대 인가요': 32463,
#  '인가요 만약': 45528,
#  '만약 regression': 30735,
#  'regression 문제': 14761,
#  '문제 경우': 31961,
#  '경우 class': 21260,
#  'class name': 4737,
#  'name 파라미터': 12329,
#  '파라미터 사용': 52160,
#  '사용 나요': 34875,
#  '나요 공식': 24476,
#  '공식 문서': 21940,
#  '문서 에서': 31840,
#  '에서 classification': 40686,
#  'classification 관련': 4775,
#  '관련 파라미터': 22186,
#  '파라미터 라고': 52150,
#  '라고 소개': 29687,
#  '소개 습니다': 36676,
#  '습니다 답변': 37590,
#  '답변 부탁': 27166,
#  'yolov 가져오': 19397,
#  '가져오 backbone': 19702,
#  'backbone 학습': 4016,
#  '학습 시켜서': 53503,
#  '시켜서 가중치': 38212,
#  '가중치 업데이트': 19758,
#  '업데이트 head': 40426,
#  'head 과정': 8616,
#  '과정 통해': 22025,
#  '통해 문제': 51922,
#  '문제 해결': 32146,
#  '해결 위한': 54266,
#  '위한 새로운': 43121,
#  '새로운 모델': 35441,
#  '모델 만들': 31290,
#  '만들 다고': 30659,
#  '다고 봐도': 26330,
#  '봐도 될까요': 33817,
#  '스턴스 라는': 37313,
#  '라는 무엇': 29779,
#  '무엇 인가요': 31780,
#  '인가요 네이버': 45516,
#  '네이버 는데': 25040,
#  '는데 용어': 25801,
#  '용어 생소': 42879,
#  '생소 이해': 35683,
#  '이해 습니다': 45368,
#  'boosting 수업': 4315,
#  '수업 에서': 36861,
#  '에서 xgboost': 40918,
#  'xgboost 패키지': 19267,
#  '패키지 사용': 52538,
#  '사용 실습': 34928,
#  '실습 는데': 38448,
#  '는데 sklean': 25470,
#  'sklean 에서': 16227,
#  '에서 ensemble': 40725,
#  'ensemble 패키지': 6893,
#  '패키지 radientboostingclassifier': 52534,
#  'radientboostingclassifier 습니다': 14523,
#  '습니다 모델': 37626,
#  '모델 검색': 31262,
#  '검색 속도': 20900,
#  '속도 에서': 36730,
#  '에서 xgboosting': 40919,
#  'xgboosting 다고': 19270,
#  '다고 나와': 26309,
#  '나와 는데': 24357,
#  '는데 속도': 25725,
#  '속도 모델': 36729,
#  '모델 차이': 31352,
#  '차이 장단점': 49837,
#  '장단점 는지': 46891,
#  '는지 궁금': 26056,
#  '세요 84': 36363,
#  '84 db': 2752,
#  'db 서브': 5889,
#  '서브 그룹': 35767,
#  '그룹 85': 23229,
#  '85 가용': 2777,
#  '가용 영역': 19633,
#  '영역 자체': 42032,
#  '자체 습니다': 46603,
#  '습니다 원격': 37747,
#  '지원 요청': 49225,
#  '요청 드립니다': 42828,
#  '최적 max': 50474,
#  'depth 구하': 6084,
#  '구하 위해': 22633,
#  '위해 사진': 43173,
#  '사진 같이': 35096,
#  '같이 for': 20219,
#  'for 돌렸': 7830,
#  '돌렸 는데': 28217,
#  '는데 에러': 25774,
#  '납니다 그런': 24728,
#  '그런 걸까요': 23072,
#  '시간 대만': 37982,
#  '대만 추출': 27354,
#  '추출 려고': 50634,
#  '려고 저렇게': 30107,
#  '저렇게 조건식': 46955,
#  '조건식 더니': 48375,
#  '더니 오류': 27673,
#  '뜹니다 day': 29541,
#  'day df': 5841,
#  'df loc': 6166,
#  'loc df': 11160,
#  'df hour': 6157,
#  'hour 10': 8742,
#  '10 11': 269,
#  '11 12': 611,
#  '12 13': 733,
#  '13 14': 822,
#  '14 15': 876,
#  '15 16': 908,
#  '16 17': 971,
#  '17 18': 1041,
#  '18 19': 1081,
#  '19 이것': 1148,
#  '이것 고요': 44468,
#  '고요 잘못': 21823,
#  '잘못 을까요': 46848,
#  '을까요 추출': 44240,
#  '추출 는지': 50633,
#  'cont variable': 5159,
#  'variable torch': 18711,
#  'torch longtensor': 17726,
#  'longtensor cont': 11236,
#  'cont view': 5160,
#  'view 여기': 18819,
#  '여기 view': 41503,
#  'view 인자': 18820,
#  '인자 batch': 45762,
#  'batch size': 4079,
#  'size 들어가': 16215,
#  '들어가 나요': 28977,
#  '나요 02': 24424,
#  '02 intent': 117,
#  'intent analysis': 9977,
#  'analysis cnn': 3351,
#  'cnn 파일': 4836,
#  '파일 에서': 52387,
#  '에서 training': 40897,
#  'training test': 17925,
#  'test 모두': 17279,
#  '모두 에서': 31471,
#  '에서 batch': 40672,
#  'batch 단위': 4080,
#  '단위 데이터': 27073,
#  '데이터 입력': 27974,
#  '입력 하나': 46388,
#  '하나 들어가': 53310,
#  '들어가 때문': 28985,
#  '때문 view': 29326,
#  'view 인지': 18821,
#  '인지 궁금': 45785,
#  '합니다 만약': 54032,
#  '만약 이전': 30765,
#  '이전 파일': 45288,
#  '파일 dataset': 52238,
#  'dataset 들어온다면': 5771,
#  '들어온다면 batch': 29043,
#  'size 100': 16186,
#  '100 라면': 472,
#  '라면 variable': 29859,
#  'view 100': 18809,
#  '100 인가요': 485,
#  'aimodel 모델': 3241,
#  '모델 외래': 31328,
#  '외래 키로': 42710,
#  '키로 result': 51569,
#  'result 설정': 15084,
#  '설정 상태': 36141,
#  '상태 에서': 35371,
#  '에서 views': 40909,
#  'views py': 18831,
#  'py 에서': 14435,
#  '에서 어떻': 41207,
#  '어떻 result': 39936,
#  'result 모델': 15078,
#  '모델 는지': 31272,
#  '는지 모르': 26088,
#  '10 bike': 314,
#  'bike bike': 4189,
#  '여소 ascending': 41657,
#  'bar bike': 4036,
#  'bike 여소': 4210,
#  '여소 bike': 41658,
#  'bike 이용': 4213,
#  '건수 1000': 20728,
#  '1000 plt': 518,
#  'show 는데': 16103,
#  '는데 그래프': 25563,
#  '그래프 여소': 22993,
#  '여소 엄청': 41662,
#  '엄청 두껍': 40417,
#  '두껍 나오': 28618,
#  '나오 나머지': 24181,
#  '나머지 나와요': 24124,
#  '나와요 잘못': 24408,
#  '첨부 그래프': 50270,
#  '그래프 처럼': 23002,
#  '처럼 세로': 50102,
#  '세로 길이': 36303,
#  '길이 경우': 23716,
#  '경우 스크롤': 21413,
#  '스크롤 도록': 37272,
#  '도록 크기': 28078,
#  '크기 조절': 51474,
#  '조절 방법': 48449,
#  '방법 을까요': 32748,
#  '을까요 plt': 44159,
#  '10 이런': 398,
#  '이런 으로': 44699,
#  '으로 크기': 43834,
#  '크기 확대': 51481,
#  '확대 처럼': 55462,
#  '처럼 커져서': 50137,
#  '커져서 스크롤': 51010,
#  '스크롤 많이': 37273,
#  '많이 해야': 30833,
#  '해야 해서': 54815,
#  '해서 질문': 54659,
#  '셀프 테스트': 36641,
#  '테스트 시험': 51720,
#  '시험 종료': 38329,
#  '종료 설문': 48563,
#  '설문 들어간다는': 36082,
#  '들어간다는 잘못': 29026,
#  '잘못 셀프': 46838,
#  '테스트 접속': 51734,
#  '접속 습니다': 47513,
#  '습니다 처리': 37826,
#  '처리 일까요': 50193,
#  '현재 tab': 54996,
#  'tab 이름': 17030,
#  '이름 worker': 44861,
#  'worker 실제': 19212,
#  '실제 terminal': 38561,
#  'terminal 환경': 17194,
#  '환경 까지': 55652,
#  '까지 worker': 23785,
#  'worker 아닙니다': 19213,
#  '아닙니다 상관': 39198,
#  '상관 마시': 35278,
#  '마시 ssh': 30471,
#  'ssh 통해': 16549,
#  '통해 노드': 51912,
#  '노드 접속': 25085,
#  '접속 진행': 47533,
#  '진행 으로': 49512,
#  '보입니다 마스터': 33659,
#  '마스터 노드': 30425,
#  '노드 부터': 25079,
#  '부터 진행': 34140,
#  '진행 는데': 49443,
#  '는데 이런': 25829,
#  '이런 에러': 44696,
#  '에러 네요': 40573,
#  '저희 predict': 47061,
#  'predict 첨부': 14002,
#  '첨부 사진': 50288,
#  '같이 10': 20213,
#  '10 학습': 420,
#  '학습 결과': 53471,
#  '결과 예측': 21106,
#  '예측 으로': 42211,
#  '으로 나요': 43511,
#  '나요 아니': 24541,
#  '아니 정확도': 39009,
#  '정확도 가장': 47928,
#  '가장 학습': 19681,
#  '학습 예측': 53515,
#  '예측 나요': 42176,
#  'reverseconnection 연결': 15174,
#  '연결 window': 41770,
#  'window 10': 19124,
#  '10 에서': 390,
#  '에서 해야': 41408,
#  '해야 명령어': 54758,
#  '명령어 입력': 31199,
#  '는데 attacker': 25345,
#  'attacker 에서': 3850,
#  '에서 sessions': 40865,
#  'sessions 으니깐': 15883,
#  '으니깐 invalid': 43349,
#  'invalid session': 10012,
#  'session identifier': 15865,
#  'identifier 뜹니다': 8977,
#  '뜹니다 연결': 29592,
#  '연결 어떻게': 41805,
#  '어떻게 해야': 40060,
#  '해야 나요': 54739,
#  'var new': 18692,
#  'new object': 12442,
#  'object 객체': 12905,
#  '객체 만들': 20490,
#  '만들 이용': 30701,
#  '해서 객체': 54524,
#  '객체 추가': 20495,
#  '추가 addr': 50498,
#  'addr address': 3113,
#  'address 에서': 3121,
#  '에서 이름': 41261,
#  '이름 addr': 44858,
#  'address 등등': 3120,
#  '등등 이름': 29090,
#  '이름 지정': 44901,
#  '지정 건가요': 49257,
#  '건가요 아니면': 20667,
#  '아니면 메소드': 39050,
#  '메소드 쓰이': 31054,
#  '쓰이 명령문': 38844,
#  '명령문 일까요': 31182,
#  '일까요 함수': 45959,
#  '함수 객체': 53827,
#  '추가 부분': 50549,
#  '부분 에서': 33985,
#  '에서 getinfo': 40743,
#  'getinfo function': 8155,
#  'function getinfo': 8019,
#  'getinfo 대해서': 8156,
#  '대해서 메소드': 27602,
#  '메소드 인지': 31058,
#  '인지 이름': 45824,
#  '지정 건지': 49258,
#  '항상 자세히': 54220,
#  '자세히 설명': 46572,
#  '설명 셔서': 36045,
#  '드립니다 그럼': 28798,
#  '그럼 fetch': 23160,
#  'fetch xhr': 7493,
#  'xhr 정적': 19275,
#  '정적 페이지': 47834,
#  '페이지 변경': 52608,
#  '변경 url': 33166,
#  'url 결과': 18292,
#  '결과 reponse': 21037,
#  'reponse 위함': 14859,
#  '위함 건가요': 43133,
#  '세요 rds': 36419,
#  'rds 스턴스': 14664,
#  '스턴스 연결': 37328,
#  '연결 명령어': 41791,
#  '명령어 command': 31183,
#  'command not': 5033,
#  'not found': 12631,
#  'found 라고': 7901,
#  '라고 나옵니다': 29646,
#  '나옵니다 어서': 24333,
#  '어서 사용': 40180,
#  '사용 어서': 34936,
#  '어서 그런': 40134,
#  '그런 은데': 23078,
#  '은데 원격': 44092,
#  '원격 으로': 42972,
#  '으로 검수': 43455,
#  '검수 부탁': 20920,
#  '부탁 드려도': 34066,
#  '드려도 될까요': 28662,
#  'train validation': 17862,
#  'validation split': 18524,
#  'split 부분': 16458,
#  '부분 무엇': 33950,
#  '무엇 으로': 31776,
#  '으로 해야': 43874,
#  '는지 는데': 26067,
#  '는데 각각': 25521,
#  '각각 지정': 19914,
#  '지정 선언': 49277,
#  '해야 할까요': 54810,
#  '할까요 아니': 53736,
#  '아니 그냥': 38957,
#  '그냥 바로': 22835,
#  '바로 지정': 32433,
#  '지정 나요': 49262,
#  '나요 그리고': 24484,
#  ...}

# %%
np.where(vect.transform(x_train).toarray()[0]==0, 1, 0).sum() / len(vect.transform(x_train).toarray()[0])
# Out:
# 0.9991761735050235

# %%
len(vect.vocabulary_)
# Out:
# 55837

# %%
vect.transform(x_train).shape
# Out:
# (2964, 55837)

# %%
bi_gram_train = vect.transform(x_train)
bi_gram_val = vect.transform(x_val)

# %%
bi_gram_train.shape
# Out:
# (2964, 55837)

# %% [markdown]
# ### 6-3. Sequence (keras, whatever)
# > * [keras text classification](https://keras.io/examples/nlp/text_classification_from_scratch/)
# > * [tensorflow text classification](https://www.tensorflow.org/tutorials/keras/text_classification)
# * tokenizer.fit_on_texts() : 주어진 텍스트 데이터에 대해 단어 사전 생성
# * 문장 길이 분포 살펴보기
# * 문장 길이를 구해서 기초통계량, histogram, boxplot을 그려보고 적절한 개수를 결정합니다.
# * tokenizer.texts_to_sequences() : 주어진 텍스트 데이터를 정수 시퀀스로 변환

# %%
x_train
# Out:
# 3002    안녕 하 세요 질문 드립니다  stu 01    no  1   name   홍길동 ...
# 2724     5  검증  예측 pl  ml  predict  x  val  pl pl  rea...
# 80      지금 현재 문자열 에서 float 으로 변환 하 는 것 은 불 가능 으로 보입니다 ...
# 2607    kubeadm join 제 꺼 복 붙 하고 입력 했 는데 저렇게 중간 에 잘리 고 ...
# 1723    수치 화 과정 에서 Age 열 에 결 측 치가 있 어 결 측 치 를 제거 했 더니 ...
#                               ...
# 2553    test dataset 을 detect 를 할 때  모델 이 예측 한 각 objec...
# 2694    RTB 에 대해 생각 하 다가 의문 이 하나 들 었 습니다  1  보통 키오스 크 ...
# 2415    항상 자세 한 설명 감사 드립니다  금방 강의 중 with open  f  path...
# 3254    Yes  data  loc  data   US  Yes   Sales  No  da...
# 182     elements  dom  select   gBestWrap  gt  div  gt...
# Name: morphs, Length: 2964, dtype: object

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
tk = Tokenizer(lower=False)
tk.fit_on_texts(x_train)
train_seq = tk.texts_to_sequences(x_train)
val_seq = tk.texts_to_sequences(x_val)

# %%
len(tk.word_index) # token 개수
# Out:
# 9426

# %%
count = 0
for k, v in tk.word_counts.items():
    if v < 2:
        count += 1
count
# Out:
# 3510

# %%
max_words = len(tk.word_index) - count + 1

tk = Tokenizer(num_words=max_words, lower=False)
tk.fit_on_texts(x_train)
train_seq = tk.texts_to_sequences(x_train)
val_seq = tk.texts_to_sequences(x_val)

# %%
sns.histplot([len(x) for x in train_seq]) # tokenize 된 결과의 길이 분포도
# Out:
# <Axes: ylabel='Count'>

# %%
max([len(x) for x in train_seq]), min([len(x) for x in train_seq])
# Out:
# (927, 3)

# %%
temp = np.array([len(x) for x in train_seq])
max_idx = np.where(temp == 927)[0][0]
min_idx = np.where(temp == 3)[0][0]

# %%
tk.sequences_to_texts([train_seq[max_idx]])
# Out:
# ['NoSuchElementException Traceback most recent call last in gt 1 title cafe element cafe find element By CSS SELECTOR arrticle text anaconda 3 lib site packages selenium webdriver remote webelement py in find element self by value 417 value name s value 418 gt 419 return self execute Command FIND CHILD ELEMENT 420 using by value value value 421 anaconda 3 lib site packages selenium webdriver remote webelement py in execute self command params 394 params 395 params id self id gt 396 return self parent execute command params 397 398 def find element self by By ID value None gt WebElement anaconda 3 lib site packages selenium webdriver remote webdriver py in execute self driver command params 433 response self command executor execute driver command params 434 if response gt 435 self error handler check response response 436 response value self unwrap value 437 response get value None anaconda 3 lib site packages selenium webdriver remote errorhandler py in check response self response 245 alert text value alert get text 246 raise exception class message screen stacktrace alert text type ignore call arg mypy is not smart enough here gt 247 raise exception class message screen stacktrace 248 249 def value or default self obj Mapping KT VT key KT default VT gt VT NoSuchElementException Message no such element Unable to locate element method css selector selector arrticle Session info chrome 104 0 5112 80 Stacktrace Backtrace Ordinal 0 0 x 00 AA 78 B 3 2193587 Ordinal 0 0 x 00 A 40681 1771137 Ordinal 0 0 x 009541 A 8 803240 Ordinal 0 0 x 009824 A 0 992416 Ordinal 0 0 x 0098273 B 993083 Ordinal 0 0 x 00978 C 81 953473 Ordinal 0 0 x 0099 D 7 F 4 1103860 Ordinal 0 0 x 00978 C 04 953348 Ordinal 0 0 x 0099 D 9 C 4 1104324 Ordinal 0 0 x 009 ADAE 2 1170146 Ordinal 0 0 x 0099 D 5 C 6 1103302 Ordinal 0 0 x 009777 E 0 948192 Ordinal 0 0 x 009786 E 6 952038 GetHandleVerifier 0 x 00 D 50 CB 2 2738370 GetHandleVerifier 0 x 00 D 421 B 8 2678216 GetHandleVerifier 0 x 00 B 317 AA 512954 GetHandleVerifier 0 x 00 B 30856 509030 Ordinal 0 0 x 00 A 4743 B 1799227 Ordinal 0 0 x 00 A 4 BB 68 1817448 Ordinal 0 0 x 00 A 4 BC 55 1817685 Ordinal 0 0 x 00 A 55230 1856048 BaseThreadInitThunk 0 x 75 F 7 FA 29 25 R t l G e t A p pContainerNamedObjectPath 0 x 77637 A 9 E 286 R t l G e t A Traceback most recent call last in gt 1 title cafe element cafe find element By CSS SELECTOR arrticle text anaconda 3 lib site packages selenium webdriver remote webelement py in find element self by value 417 value name s value 418 gt 419 return self execute Command FIND CHILD ELEMENT 420 using by value value value 421 anaconda 3 lib site packages selenium webdriver remote webelement py in execute self command params 394 params 395 params id self id gt 396 return self parent execute command params 397 398 def find element self by By ID value None gt WebElement anaconda 3 lib site packages selenium webdriver remote webdriver py in execute self driver command params 433 response self command executor execute driver command params 434 if response gt 435 self error handler check response response 436 response value self unwrap value 437 response get value None anaconda 3 lib site packages selenium webdriver remote errorhandler py in check response self response 245 alert text value alert get text 246 raise exception class message screen stacktrace alert text type ignore call arg mypy is not smart enough here gt 247 raise exception class message screen stacktrace 248 249 def value or default self obj Mapping KT VT key KT default VT gt VT NoSuchElementException Message no such element Unable to locate element method css selector selector arrticle Session info chrome 104 0 5112 80 Stacktrace Backtrace Ordinal 0 0 x 00 AA 78 B 3 2193587 Ordinal 0 0 x 00 A 40681 1771137 Ordinal 0 0 x 009541 A 8 803240 Ordinal 0 0 x 009824 A 0 992416 Ordinal 0 0 x 0098273 B 993083 Ordinal 0 0 x 00978 C 81 953473 Ordinal 0 0 x 0099 D 7 F 4 1103860 Ordinal 0 0 x 00978 C 04 953348 Ordinal 0 0 x 0099 D 9 C 4 ...

# %%
tk.sequences_to_texts([train_seq[min_idx]])
# Out:
# ['지원 부탁 드립니다']

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
max_len = 400
train_seq = pad_sequences(train_seq, maxlen=max_len, padding='pre', truncating='post') # padding은 앞, truncating은 뒤
val_seq = pad_sequences(val_seq, maxlen=max_len, padding='pre', truncating='post') # padding은 앞, truncating은 뒤

# %% [markdown]
# ### 6-4. Word2Vec (gensim, optional)
# > * [gensim-word2vec-tutorial](https://radimrehurek.com/gensim/auto_examples/tutorials/run_word2vec.html#sphx-glr-auto-examples-tutorials-run-word2vec-py)
# > * [tensorflow-word2vec-tutorial](https://www.tensorflow.org/tutorials/text/word2vec?hl=ko)

# %%
# 아래 함수는 제공합니다.
def get_sent_embeddings(model, embedding_size, tokenized_words):

    # 단어 임베딩 및 n_words의 크기가 0인 feature_vec 배열을 0으로 초기화합니다. 
    # 또한 model.wv.index2word를 사용하여 Word2Vec 모델의 어휘에 단어 세트를 생성합니다.
    feature_vec = np.zeros((embedding_size,), dtype='float32')
    n_words = 0
    index2word_set = set(model.wv.index_to_key)

    # 토큰화된 문장의 각 단어를 반복하고 Word2Vec 모델의 어휘에 존재하는지 확인합니다. 
    # 그렇다면 n_words가 증가하고 단어의 임베딩이 feature_vec에 추가됩니다.
    for word in tokenized_words:
        if word in index2word_set:
            n_words += 1
            feature_vec = np.add(feature_vec, model.wv[word])
    
    # Word2Vec 모델의 어휘에 있는 입력 문장에 단어가 있는지 확인합니다. 
    # 있다면 feature_vec를 n_words로 나누어 입력 문장의 평균 임베딩을 구합니다.
    if (n_words > 0):
        feature_vec = np.divide(feature_vec, n_words)
        
    return feature_vec
def get_dataset(sentences, model, num_features):

    # 각 문장에 대한 임베딩을 보유할 dataset이라는 빈 목록을 초기화합니다.
    dataset = list()

    # 문장의 각 문장을 반복하고 앞에서 설명한 get_sent_embeddings() 함수를 사용하여 문장에 대한 평균 임베딩을 생성합니다. 
    # 결과 문장 임베딩이 데이터 세트 목록에 추가됩니다.
    for sent in sentences:
        dataset.append(get_sent_embeddings(model, num_features, sent))

    # 루프에서 생성된 문장 임베딩을 sent_embedding_vectors라는 2차원 배열에 쌓습니다. 
    sent_embedding_vectors = np.stack(dataset)
    
    return sent_embedding_vectors

# %%
from tqdm import tqdm
# 불용어 정의
stopwords = ['의','가','이','은','들','는','좀','잘','걍','과','도','를','으로','자','에','와','한','하다']

# 형태소 분석기 OKT를 사용한 토큰화 작업 (다소 시간 소요)
okt = Okt()

tokenized_data = []
for sentence in tqdm(x_train):
    tokenized_sentence = okt.morphs(sentence, stem=True) # 토큰화
    stopwords_removed_sentence = [word for word in tokenized_sentence if not word in stopwords] # 불용어 제거
    tokenized_data.append(stopwords_removed_sentence)
# Out:
# 100%|██████████| 2964/2964 [00:20<00:00, 147.68it/s]

# %%
temp = np.array([len(x) for x in tokenized_data])
print('최대 길이 :', temp.max())
print('평균 길이 :', temp.mean())
print('최소 길이 :', temp.min())

plt.subplot(2, 1, 1)
sns.histplot(temp)
plt.subplot(2, 1, 2)
sns.boxplot(x=temp)
plt.show()
# Out:
# 최대 길이 : 929
# 평균 길이 : 55.32557354925776
# 최소 길이 : 3

# %%
from gensim.models import Word2Vec

model = Word2Vec(sentences=tokenized_data)

# %%
model.wv.vectors.shape
# Out:
# (2993, 100)

# %%
model.wv.most_similar('코드')
# Out:
# [('아래', 0.9603841304779053),
#  ('다음', 0.949346661567688),
#  ('작성', 0.9443093538284302),
#  ('사진', 0.9389652609825134),
#  ('같이', 0.938406765460968),
#  ('이다', 0.9271536469459534),
#  ('계속', 0.9224264621734619),
#  ('처럼', 0.8954299092292786),
#  ('실행', 0.8930140733718872),
#  ('면서', 0.883171796798706)]

# %%
w2v_x_train = get_dataset(x_train, model, 100)
w2v_x_val = get_dataset(x_val, model, 100)

# %% [markdown]
# ### 6-5. 데이터 저장하기
# * N-gram, Sequence로 처리한 데이터 저장
# * sparse data에 대해서는 scipy.sparse.save_npz 활용

# %%
import scipy
save_path = '/content/drive/MyDrive/에이블스쿨/실습파일/2023.04.03_미니프로젝트4차_실습자료/'
scipy.sparse.save_npz(save_path + 'bigram_x_train.npz', bi_gram_train)
scipy.sparse.save_npz(save_path + 'bigram_x_val.npz', bi_gram_val)

# %%
y_train.to_csv(save_path + 'y_train.csv', index=False)
y_val.to_csv(save_path + 'y_val.csv', index=False)

# %%
np.save(save_path + 'seq_x_train', train_seq)
np.save(save_path + 'seq_x_val', val_seq)

# %%
np.save(save_path + 'w2v_x_train', w2v_x_train)
np.save(save_path + 'w2v_x_val', w2v_x_val)
